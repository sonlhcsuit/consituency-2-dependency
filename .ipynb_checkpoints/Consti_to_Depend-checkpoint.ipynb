# %% [markdown]
# #1. Import thư viện

# %%
import re
import nltk
import pprint
import copy
from pprint import pprint
from nltk.tree import Tree
from itertools import groupby

# %% [markdown]
# # 2. Các function thông dụng

# %%
# Dùng luật để kiểm tra label có phải là head hay không
def is_head(rule, label):
  return re.search(rule, label)

# %%
# Vì lúc tìm headword cho các address(kiểu list) của các phrase
# thì return về dic[address]=headword nhưng dic không lưu đc dạng list -> đổi list thành string
# Nên khi sài lại address thì cần chuyển đổi list(kiểu string) thành real list
def str_to_list(s):
  result = []
  num = ''
  for i in s:
    if i != '[' and i !=']':
      if i != ',':
        if i.isnumeric():
          num +=i
      else: 
        result.append(int(num))
        num = ''
  result.append(int(num))
  return result

# %%
# Lấy tất cả index của các cây con 
def get_all_index_in_tree(tree):
  result = []
  for index, subtree in enumerate(tree):
    if type(subtree) != str:
      result.append([index])
  return result

# %%
# Trả về cây con thông qua địa chỉ
def get_subtree(subtree_address, tree):
  if type(subtree_address) == str:
    if subtree_address == 'root':
      return tree
    else:
      subtree_address = str_to_list(subtree_address) 
  for index in subtree_address:
    tree = tree[index]
  return tree

# %%
#Khám phá tất cả các phrases.
#Sử dụng thuật toán bfs - tìm kiếm theo chiều rộng
def get_all_subtree_address(tree):
  queue = get_all_index_in_tree(tree)
  explored = []
  while queue:
    node = queue.pop(0)
    if node not in explored:
      explored.append(node)
      subtree = get_subtree(node,tree)
      index_subtree_list = get_all_index_in_tree(subtree)
      for index_subtree in index_subtree_list:
        queue.append(node+index_subtree)
  return explored

# %%
#Do có thể xuất hiện nhiều từ giống nhau trong 1 câu
#Nên sẽ khó xác định đâu là headword của phrase
#-> Số hóa các từ trong câu: Mỗi từ sẽ biến đổi thành một số, số hóa bắt đầu từ số 1 
def from_word_to_number(tree):
  for index, leafPos in enumerate(tree.treepositions('leaves')):
    tree[leafPos] = str(index+1)
  return tree

# %%
#Trong lúc đề xuất luật infer dependency label cần xét cả nhãn gốc của từ 
#Nhãn gốc là node gần nhất với node lá(từ)
def get_POS_of_word(tree):
  result = {}
  for leafPos in tree.treepositions('leaves'):
    word = tree[leafPos]
    POS = tree[leafPos[:-1]].label()
    result[word] = POS
  return result

# %%
#Trả về danh sách các nhãn gốc của từ, dùng để điền vào format CONLLU
#Lưu ý: đối vs các nhãn NULL thì không lấy 'NONE' làm nhãn gốc
#Vì NONE no-use trong việc relink khi NULL làm head ở phần hậu xử lý 
def get_all_POS(tree):
  result = []
  for leafPos in tree.treepositions('leaves'):
    i = -1
    POS = tree[leafPos[:i]].label().split('-')[0]
    while POS == 'NONE':
      i = i - 1
      POS = tree[leafPos[:i]].label().split('-')[0]
    result.append(POS)
  return result

# %%
#Follow theo Choi's guideline, lưu function_tag như đặc trưng phụ, được điền vào format CONLLU
#Trả về function_tag của C(node cao nhất của headword)
def get_function_tag(tree):
  headword_of_phrase = assign_headword_for_phrase(tree)[0]
  C_of_headword = get_C_of_headword(headword_of_phrase)
  function_tags_of_word = {}
  for word in tree.leaves():
    C_label = get_subtree(C_of_headword[word], tree).label()
    function_tags = C_label.split('-')
    temp = []
    for function_tag in function_tags:
      if function_tag in ['PRD', 'CMP', 'LGS', 'CMP', 'MDP', 'TMP', 'LOC', 'MNR', 'PRP', 'ADV', 'CND', 'CNC']:
        temp.append(function_tag)
    if temp:
      temp = '-'.join(temp)
      function_tags_of_word[word] = temp
    else:
      function_tags_of_word[word] = '_'
  return function_tags_of_word

# %% [markdown]
# #3. Tìm headword cho các phrase
# **Các bước cụ thể:**
#
# + Bước 1: Tìm head cho các phrase
# + Bước 2: Loop bước 1 đi sâu xuống cây để xác định được headword
#
# **Lưu ý trong bước 1:**
#
#   Nếu số phần tử list head trả về > 1 thì xét:
#   + Nếu các label trong list head **giống nhau** thì thực hiện gán nhãn conjunction
#   + Nếu các label trong list head **khác nhau**:
#     + Xét trong khoảng từ first label đến last label trong list head có các nhãn như Cp, CONP, UCP thì gán nhãn conjunction.
#     + Nếu không phải trường hợp conjunction thì xét theo luật phụ

# %%
# Trả về list các vị trí(index) có thể làm head và list label ứng với list các index 
def finding_head_of_tree(tree):
#Một số thay đổi:
#đổi VP, S ở S, và thêm PRD và VP, S ở SBAR thành VP, S, SBAr
# THÊM sQ vào S ở S và SBAR
# SQ: VP, Sq, S -> thêm VP và S
# thêm SPL
# Xem SPL như S ở S và SBAR
# Đảo -PRD trc S|SQ|SPL của S
# tÁCH VP thành 2 loại ở S
  head_percolation_rules = {
    "S":["-H$","^VP(-CMP|_|$)","-PRD$","^VP-","^(S|SQ|SPL)(-|_|$)","^ADJP(-|_|$)","^NP(-|_|$)"],
    "SBAR":["-H$","^VP(-|_|$)","^(S|SQ|SPL)(-|_|$)","^SBAR(-|_|$)","^ADJP(-|_|$)","^NP(-|_|$)"],
    "SQ": ["-H$","^VP(-|_|$)","^QVP(-|_|$)","^SQ(-|_|$)","^S(-|_|$)","^ADJP(-|_|$)","^NP(-|_|$)", "^QPP(-|_|$)"],
    "NP":["-H$","^NP(-|_|$)","^(Nc|Ncs|Nu|Nun|Nt|Nq|Num|Nw|Nr|Nn)(-|_|$)","^(Pd|Pp)(-|_|$)","^VP(-|_|$)"],
    "VP":["-H$","^VP(-|_|$)","^(Ve|Vc|D|Vcp|Vv)(-|_|$)","^(An|Aa)(-|_|$)","^ADJP(-|_|$)","^(Nc|Ncs|Nu|Nun|Nt|Nq|Num|Nw|Nr|Nn)(-|_|$)","^NP(-|_|$)","^SBAR(-|_|$)","^S(-|_|$)","^R(-|_|$)","^RP(-|_|$)","^PP(-|_|$)"],
    "ADJP":["-H$","^ADJP(-|_|$)","^(An|Aa)(-|_|$)","^(Nc|Ncs|Nu|Nun|Nt|Nq|Num|Nw|Nr|Nn)(-|_|$)","^S(-|_|$)"],
    "RP":["-H$","^RP(-|_|$)","^R(-|_|$)","^NP(-|_|$)"],
    "PP":["-H$","^PP(-|_|$)","^Cs(-|_|$)","^VP(-|_|$)","^SBAR(-|_|$)","^ADJP(-|_|$)","^QP(-|_|$)"],
    "ADJP":["-H$","^ADJP(-|_|$)","^A(-|_|$)","^N(-|_|$)","^S(-|_|$)"],
    "QP":["-H$","^QP(-|_|$)","^Nq(-|_|$)","^Num(-|_|$)","^Nw(-|_|$)"],
    "XP":["-H$","^XP(-|_|$)","^X(-|_|$)"],
    "YP":["-H$","^YP(-|_|$)","^Y(-|_|$)"],
    "MDP":["-H$","^MDP(-|_|$)", "^E(-|_|$)", "^(An|Aa)(-|_|$)","^(Pd|Pp)(-|_|$)", "^R(-|_|$)", "^X(-|_|$)"],
    "QNP":["-H$","^QNP(-|_|$)","^NP(-|_|$)","^(Nc|Ncs|Nu|Nun|Nt|Nq|Num|Nw|Nr|Nn)(-|_|$)","^(Pd|Pp)(-|_|$)"],
    "QADJP":["-H$","^QADJP(-|_|$)","^(An|Aa)(-|_|$)","^(Nc|Ncs|Nu|Nun|Nt|Nq|Num|Nw|Nr|Nn)(-|_|$)","^(Ve|Vc|D|Vcp|Vv)(-|_|$)","^(Pd|Pp)(-|_|$)","^X(-|_|$)"],
    "QRP":["-H$","^QRP(-|_|$)","^(Pd|Pp)(-|_|$)","^Cs(-|_|$)","^X(-|_|$)"],
    "QPP":["-H$","^QPP(-|_|$)","^Cs(-|_|$)","^(Pd|Pp)(-|_|$)","^X(-|_|$)"],
    "QXP":["-H$","^XP(-|_|$)","^X(-|_|$)"],
    "QVP":["-H$","^(Ve|Vc|D|Vcp|Vv)(-|_|$)"],
    "UCP":["-H$"],
    "SPL":["-H$","^VP(-|_|$)","^SPL(-|_|$)", "^ADJP(-|_|$)","^NP(-|_|$)"]
    }

  phrase_type = tree.label().split('-')[0]

  head_index_result = []
  head_label_result = []
  if  phrase_type not in head_percolation_rules:
    for index, element in enumerate(tree):
      label_of_element = element.label()
      if is_head("-H$", label_of_element):
        head_index_result.append([index])
        head_label_result.append(label_of_element)

    if head_index_result:
      return head_index_result, head_label_result
    else:
      return [[0]], [tree[0].label()] 

  if phrase_type == 'RP':
    for rule in head_percolation_rules['RP']:
      if not head_index_result:
        for index, element in zip(range(len(tree)-1, -1, -1), reversed(tree)):
          label_of_element = element.label()
          if is_head(rule, label_of_element):
            head_index_result.append([index])
            head_label_result.append(label_of_element)
      else: 
        break
        
    if head_index_result:
      return head_index_result[::-1], head_label_result[::-1]
    else: 
      return [[0]], [tree[0].label()] 
    
  else:
    for rule in head_percolation_rules[phrase_type]:
      if not head_index_result:
        for index, element in enumerate(tree):
          label_of_element = element.label()
          if is_head(rule, label_of_element):
            head_index_result.append([index])
            head_label_result.append(label_of_element)
      else: 
        break
        
    if head_index_result:
      return head_index_result, head_label_result
    else: 
      return [[0]], [tree[0].label()]

# %%
# Hàm dùng trong trường hợp các label trong head list khác nhau:
# Hàm lấy các label trong khoảng từ first label -> last label trong head list 
# Để xét coi có Cp, UCP, CONJP
def deepen_head_list(mother_tree, tree_address, head_index_list):
  deep_address_list = []
  deep_label_list = []
  first_index = head_index_list[0][0]
  last_index = head_index_list[-1][0]
  for index in range(first_index, last_index+1):
    if tree_address != 'root':
      subtree_address = tree_address + [index]
    else:
      subtree_address = [index]
    deep_address_list.append(subtree_address)
    deep_label_list.append(get_subtree(subtree_address, mother_tree).label())
  return deep_address_list, deep_label_list

# %%
# Dán nhãn conjunction 
def get_conjunction(P_address, C_address_list, C_label_list):
  P_of_C_dic = {}
  previous_C_address = str(C_address_list[0])
  for C_address, C_label in zip(C_address_list[1:], C_label_list[1:]):
    if C_label == 'PU':
      P_of_C_dic[str(C_address)] = (previous_C_address, 'PUNCT')
    elif re.search('^(Cp|CONJP)', C_label):
      P_of_C_dic[str(C_address)] = (previous_C_address, 'CC')
    else:
      P_of_C_dic[str(C_address)] = (previous_C_address, 'CONJ')
    if (C_label != 'PU') and (C_label != 'Cp') and ('CONJP' not in C_label):
      previous_C_address = str(C_address)
  return P_of_C_dic

# %%
# Kiểm tra có phải là trường hợp conj hay không
def is_conjunction(C_label_list):

  unique = set(C_label_list)
  if len(unique) == 3:
    if ('PU' in unique) and ((('Cp' in unique) or ('CONJP' in unique)) and (('Cp' != C_label_list[0]) or ('CONJP' != C_label_list[0]))):
      return True
    elif (('PU' in unique) or ('Cp' in unique) or ('CONJP' in unique)) and ('SPL' in unique) and ('S' in unique):
      return True
  elif len(unique) == 2:
    if ('PU' in unique) or ((('Cp' in unique) or ('CONJP' in unique)) and (('Cp' != C_label_list[0]) or ('CONJP' != C_label_list[0]))):
      return True
    elif ('SPL' in unique) and ('S' in unique):
      return True
  elif len(unique) == 1:
    return True
  return False

def has_same_phrase_type(C_label_list):
  phrase_type_set= set()
  for C_label in C_label_list:
    phrase_type = C_label.split('-')[0]
    phrase_type_set.add(phrase_type)
    if len(phrase_type_set) == 2:
      return False
  return True

#Dùng xác định head khi head list > 1
def identify_head(tree, P_address, C_address_list, C_label_list, head_C_address_list, head_C_label_list):

  if is_conjunction(C_label_list):
    P_of_C_dic = get_conjunction(P_address, C_address_list, C_label_list)
    return [C_address_list[0], P_of_C_dic]

  if has_same_phrase_type(head_C_label_list):
    if (('Cp' in C_label_list) or ('CONJP' in C_label_list)) and (C_label_list[0] != 'Cp') and (C_label_list[0] != 'CONJP'):
      P_of_C_dic = get_conjunction(P_address, C_address_list, C_label_list)
      return [C_address_list[0], P_of_C_dic]
    else:
      first_element = head_C_address_list[0]
      if first_element[-1] >= 1:
        pre_address_of_head_C_address_list = first_element[:-1] + [first_element[-1]-1] 
        pre_subtree = get_subtree(pre_address_of_head_C_address_list, tree)
        pre_subtree_label = pre_subtree.label()
        if re.search('^(Cp|CONJP)', pre_subtree_label):
          P_of_C_dic = get_conjunction(P_address, C_address_list, C_label_list)
          return [C_address_list[0], P_of_C_dic]

    for head_C_address, head_C_label in zip(head_C_address_list, head_C_label_list):
      if '-' not in head_C_label:
        return [head_C_address]

    for head_C_address, head_C_label in zip(head_C_address_list, head_C_label_list):
      if '-SBJ' not in head_C_label:
        return [head_C_address]
  else:
    if ('Cp' in C_label_list) and (C_label_list[0] != 'Cp'):
      P_of_C_dic = get_conjunction(P_address, C_address_list, C_label_list)
      return [C_address_list[0], P_of_C_dic]

    else:
      P_phrase_type = get_subtree(P_address, tree).label().split('-')[0]
      head_exception_rules = {
          "NP":["^(Nn_swsp|Nn_w)(-|$)","^(Nn|Nu|Nun|Nt)(-|$)","^(Num|Nq|Nr)(-|$)"],
          "QP":["^Nq(-|$)","^Num(-|$)"],
          "Nn_swsp":["^(Ncs|Nc)(-|$)"],
          "VP":["^(Ve|Vc|D|Vcp|Vv)(-|$)"],
          "S":["^(S|SQ)($)"],
          "SBAR":["^(S|SQ)($)"]

      }

      for rule in head_exception_rules[P_phrase_type]:
              for head_C_address, head_C_label  in zip(head_C_address_list, head_C_label_list):
                if is_head(rule, head_C_label):
                  return [head_C_address]
  return "Nope"

# %%
# Trả về list các phrase có chung headword
def from_phrase_to_headword(mother_tree, tree, tree_address):
  phrase_to_headword = [tree_address]
  if tree_address != 'root':
    tree = get_subtree(tree_address, mother_tree)
  P_of_C_dic = {}
  while type(tree[0]) != str:
      head_index_list, head_label_list = finding_head_of_tree(tree)
      
      
      if len(head_index_list) == 1:
        if tree_address != 'root':
          tree_address = tree_address + head_index_list[0]
        else:
          tree_address = head_index_list[0]
        tree = get_subtree(tree_address, mother_tree)
        phrase_to_headword.append(tree_address)
      else:   
        address_list, label_list = deepen_head_list(mother_tree, tree_address, head_index_list)
        head_address_list = []
        for head_index in head_index_list:
          if tree_address != 'root':
            head_address_list.append(tree_address + head_index)
          else:
            head_address_list.append(head_index)
        result = identify_head(mother_tree, tree_address, address_list, label_list, head_address_list, head_label_list)
        tree_address = result[0]#tree, P_address, C_address_list, C_label_list, head_C_address_list, head_C_label_list
        tree = get_subtree(tree_address, mother_tree)
        
        phrase_to_headword.append(tree_address)
        if len(result) == 2:
          P_of_C_dic.update(result[1])  
  phrase_to_headword.append(tree[0])
  return [phrase_to_headword, P_of_C_dic]

# %%
def assign_headword_for_phrase(tree):

  P_of_C_dic = {}
  headword_of_phrase = {}
  phrase_address_list = ['root'] + get_all_subtree_address(tree)
  
  #Tìm head
  for phrase_address in phrase_address_list:
    if str(phrase_address) not in headword_of_phrase:
      if phrase_address != 'root': 
        subtree = get_subtree(phrase_address, tree)
      else:    
        subtree = tree
      if type(subtree[0]) != str:
        result = from_phrase_to_headword(tree, subtree, phrase_address)       
        phrase_to_headword = result[0][:-1]
        headword = result[0][-1] 
        P_of_C_dic.update(result[1])
        for head_phrase_address in phrase_to_headword:
          headword_of_phrase[str(head_phrase_address)] = headword
      else:
        headword_of_phrase[str(phrase_address)] = subtree[0]

  for phrase_address in get_all_subtree_address(tree):
    subtree = get_subtree(phrase_address, tree)
    label = subtree.label().split('-')[0]
    if label == 'UCP':
      C_address_list = []
      C_label_list = []
      for index_subtree in range(len(subtree)):
        subtree_address = phrase_address+[index_subtree]
        subtree_label = get_subtree(subtree_address, tree).label() 
        C_address_list.append(subtree_address)
        C_label_list.append(subtree_label)
      P_of_C_dic.update(get_conjunction(phrase_address, C_address_list, C_label_list))
  return [headword_of_phrase, P_of_C_dic]

# %% [markdown]
# #4. Dán nhãn
# Các bước cụ thể:
# + Bước 1: Xác định C(node cao nhất của headword) và P(node parent của C)
# + Bước 2: Viết luật dán nhãn được suy ra từ label của C và P

# %%
# Lấy C của word
def get_C_of_headword(headword_of_phrase):
  duplicate_headword_of_phrase = {}
  duplicate_headword_of_phrase.update(headword_of_phrase)
  del duplicate_headword_of_phrase['root']
  merge = {}
  for key, value in sorted(duplicate_headword_of_phrase.items()):
      merge.setdefault(value, []).append(key)
  C ={}
  for headword in merge:
    C[headword]=min(merge[headword], key=len)
  return C

# %%
# Lấy P của C
def get_P_of_C(phrase_address, root_address):
  if not str_to_list(phrase_address)[:-1]:
    return root_address
  return str(str_to_list(phrase_address)[:-1])

# %%
# Dán nhãn dựa trên các Luật
def get_dependency_relation(P_address, C_address, P_index, tree):
  #get C_label and P_label
  C_tree = get_subtree(C_address, tree)
  C = C_tree.label()
  P = get_subtree(P_address, tree).label()
  
  POS_of_word = get_POS_of_word(tree)
  p = POS_of_word[P_index]
  # Nếu C là UCP thì relation sẽ đc quyết bởi POS trái nhất trong cây UCP
  if 'UCP' in C:
    C = C_tree[0].label()

  #Luật
  if has_SBJ(C):
    return has_SBJ(C)
  
  if is_ADJUNCT(C):
    return is_ADJUNCT(C)
  
  if is_PARATAXIS(C):
    return is_PARATAXIS(C)
  
  if is_VOCATIVE(C):
    return is_VOCATIVE(C)

  if is_NP_ADVMOD(P, C):
    return is_NP_ADVMOD(P, C)

  if is_ADJP_ADVMOD(P, C):
    return is_ADJP_ADVMOD(P, C)

  if is_VMOD_or_RCMOD(P, C):
    return is_VMOD_or_RCMOD(P, C)

  if is_NUM(P, C):
    return is_NUM(P, C)

  if is_NN(P, C):
    return is_NN(P, C)

  if is_PREP(C):
    return is_PREP(C)
  
  if is_POBJ_or_PCOMP(P, C):
    return is_POBJ_or_PCOMP(P, C)
    
  if is_PUNCT(C):
    return is_PUNCT(C)

  if is_CLF_or_NN(P, p):
    return is_CLF_or_NN(P, p)

  if is_AMOD(P, C):
    return is_AMOD(P, C)
  
  if is_NUMBER_or_QUANTMOD(P, C):
    return is_NUMBER_or_QUANTMOD(P, C)
  
  if is_NN(P, C):
    return is_NN(P, C)
  
  if is_DET(P, C):
    return is_DET(P, C)

  if is_ATTR(p, C):
    return is_ATTR(p, C)

  if is_IOBJ(P, C):
    return is_IOBJ(P, C)
  
  if is_OBJ_or_NP_ADVMOD(P, C):
    return is_OBJ_or_NP_ADVMOD(P, C)

  if is_CCOMP_or_XCOMP_or_ADVCL(P, C, C_tree):
    return is_CCOMP_or_XCOMP_or_ADVCL(P, C, C_tree)
  
  if is_ACOMP(P, C):
    return is_ACOMP(P, C)
  
  if is_ADVCL(P, C):
    return is_ADVCL(P, C)

  if is_SINO(P):
    return is_SINO(P)

  if is_INTJ(C):
    return is_INTJ(C)
  
  if is_CC(C):
    return is_CC(C)

  if is_MARK(C):
    return is_MARK(C)
#Luật phụ
  if is_NSUBJ(C, P):
    return is_NSUBJ(C, P)

  return 'DEP'

# %% [markdown]
# ## Các luật chuyển đổi

# %%
# Hàm dùng để xác định xem  coi S có chủ ngữ không để suy ra CCOMP or XCOMP
def has_empty_subject(tree):
  if 'SBAR' in tree.label():
    for subtree in tree:
      if re.search('^S(-|$)', subtree.label()):
        for sub_subtree in subtree:
          if 'NP-SBJ' in sub_subtree.label() and 'NONE' in sub_subtree[0].label():
            return True
        return False
    return False 
  elif re.search('^S(-|$)', tree.label()):
    for subtree in tree:
      if 'NP-SBJ' in subtree.label() and 'NONE' in subtree[0].label():
        return True
    return False
  return False

# %%
# Hàm dùng để xem coi cây có thành phần POS mà mình muốn hay không
# Ví dụ xét coi cây có nhãn VP để suy ra CCOMP or XCOMP
def has_POS(tree, POS):
  if 'SBAR' in tree.label():
    for subtree in tree:
      if re.search('^S(-|$)', subtree.label()):
        for sub_subtree in subtree:
          label_sub_subtree = sub_subtree.label()
          if re.search('^{}(-|$)'.format(POS), label_sub_subtree):
            return True
        return False
    return False 

  elif re.search('^S(-|$)', tree.label()):
    for subtree in tree:
      label_subtree = subtree.label()
      if re.search('^{}(-|$)'.format(POS), label_subtree):
        return True
    return False
  return False

# %%
#S(-|$) phân biệt vs SBAR
def has_SBJ(C):
  if 'NP-SBJ' in C:
    return 'NSUBJ'
  elif 'ADJP-SBJ' in C:
    return 'ASUBJ'
  elif 'VP-SBJ' in C:
    return 'VSUBJ'
  elif ('S-SBJ' in C) or ('SPL-SBJ' in C):
    return 'CSUBJ'
  else:
    return False

def is_NSUBJ(C, P):
  if re.search('^S$', P) and re.search('^NP$', C):
    return 'NSUBJ'
  else:
    return False
# def is_VMOD_or_RCMOD(P, C):#Ve|Vc|D|Vcp|Vv
#   if re.search('^(VP)', C):
#     if re.search('^(VP|ADJP|S)', P):
#       return 'VMOD'
#     elif re.search('^(NP|QNP)', P):
#       return 'RCMOD'
#     else:
#       return False
#   elif re.search('^(NP)', P) and re.search('^(Vv)', C) :
#     return 'VMOD'
#   else:
#     return False

def is_VMOD_or_RCMOD(P, C):#Ve|Vc|D|Vcp|Vv
  if re.search('^(VP|ADJP|S)', P):
    if re.search('^(VP|Ve|Vc|D|Vcp|Vv)', C):
      return 'VMOD'
    else:
      return False
  elif re.search('^(NP|QNP)', P):
    if re.search('^(VP)', C):
      return 'RCMOD'
    elif re.search('^(Ve|Vc|D|Vcp|Vv)', C):
      return 'VMOD'
    else:
      return False
  else:
    return False

def is_NUM(P, C):
  if re.search('^(NP|QNP|Nn)', P) and re.search('^(Num|QP)', C):
    return 'NUM'
  else:
    return False

def is_NN(P, C):
  if re.search('^(NP)', P) and re.search('^(NP|ID)', C):
    return 'NN'
  else:
    return False

def is_PREP(C):
  if re.search('^(PP|QPP)', C):
    return 'PREP'
  else:
    return False

def is_POBJ_or_PCOMP(P, C):
  if re.search('^(PP|QPP)', P):
    if re.search('^(NP)', C):
      return 'POBJ'
    else:
      return 'PCOMP'
  else:
    return False
    
def is_PUNCT(C):
  if re.search('^(PU|LBRK|RBRK)', C):
    return 'PUNCT'
  else:
    return False

def is_CLF_or_NN(P, p):
  if re.search('^(Nn_swsp)', P):
    if re.search('^(Nc|Ncs)', p):
      return 'CLF'
    else:
      return 'NN'
  else:
    return False

def is_AMOD(P, C):
  if re.search('^(NP|QNP)', P) and re.search('^(Aa|An|ADJP)', C): 
    return 'AMOD'
  else:
    return False

def is_NUMBER_or_QUANTMOD(P, C):
  if re.search('^(QP)', P):
    if re.search('^(Num|Nq)', C):
      return 'NUMBER'
    else:
      return 'QUANTMOD'
  else: 
    return False 

def is_NN(P, C):
  if re.search('^(NP|QNP)', P) and re.search('^(NP|Nr|Nt|Nu|Nun|Nn)', C):
    return 'NN'
  else:
    return False

def is_DET(P, C):
  if re.search('^(NP|QNP)', P) and re.search('^(Nw|Nq|Pd|Pp)', C):
    return 'DET' 
  else:
    return False

def is_ATTR(p, C):
  if re.search('^(Vc)', p) and re.search('^(NP|QNP)(-CMP)', C):
    return 'ATTR' 
  else:
    return False

def is_IOBJ(P, C):
  if re.search('^(VP)', P) and re.search('^(NP-IOB)', C):
    return 'IOBJ'
  else:
    return False

def is_OBJ_or_NP_ADVMOD(P, C):
  if re.search('^(VP)', P) and re.search('^(NP)(-MNR)', C):
    return 'NP_ADVMOD'
  elif (re.search('^(VP|ADJP)', P) and re.search('^(NP|QNP|Nn)', C)) or ('-DOB' in C):
    return 'OBJ'
  else:
    return False

def is_CCOMP_or_XCOMP_or_ADVCL(P, C, C_tree):
  # if re.search('^(NP)', P):  
  #   if re.search('^(S)(-CMP|$)', C): # phân biệt SBAR
  #     return 'CCOMP'
  #   elif re.search('^(SBAR)(-CMP|$)', C) and C_tree[0].label() == 'Cs':
  #     return 'CCOMP'
  #   else:
  #     return 'False'
  if re.search('^(VP|NP|ADJP|SQ|S|QVP)', P):
    if re.search('^(SQ|SPL)(-|$)', C):
      return 'CCOMP'
    elif re.search('^(S)(-[0-9]|-CMP|$)', C):
      if has_empty_subject(C_tree) and has_POS(C_tree, 'VP'):
        return 'XCOMP'
      else:
        return 'CCOMP'
    elif re.search('^(SBAR)(-[0-9]|-CMP|$)', C):
      if has_empty_subject(C_tree) and has_POS(C_tree, 'VP'):
        return 'XCOMP'
      else:
        return 'CCOMP'
    elif re.search('^(SBAR)(-PRP)', C):
      return 'ADVCL'
    else:
      return False
  else:
    return False

def is_ADJUNCT(C):
  if re.search('^(R|RP|QRP)(-|$)', C):
    return 'ADJUNCT'
  else:
    return False

def is_NP_ADVMOD(P, C):
  if re.search('^((S)(-|$)|SPL|NP|ADJP|VP|SQ)', P) and re.search('^(NP)(-TMP|-MNR|-ADV|-LOC)', C):
    return 'NP_ADVMOD'
  else:
    return False

def is_ADJP_ADVMOD(P, C):
  if re.search('^(VP|S(-|$)|SPL)', P) and re.search('^(ADJP)(-MNR|-ADV|-TMP|-MDP|-LOC|-PRD)', C):
      return 'ADJP_ADVMOD'
  elif re.search('^(ADJP)', P) and re.search('^(ADJP)', C):
    return 'ADJP_ADVMOD'
  else:
    return False

def is_ACOMP(P, C):
  if re.search('^(VP)', P) and re.search('^(ADJP)(-CMP|$)', C):
    return 'ACOMP'
  else:
    return False

def is_ADVCL(P, C):
  if re.search('^(S)(-CND|-PRN|-TMP|-PRP|-ADV|-MNR|-CNC)', C):
    return 'ADVCL'
  else:
    return False

def is_PARATAXIS(C):
  if '-PRN'in C:
    return 'PARATAXIS'
  else:
    return False

def is_SINO(P):
  if '_w' in P:
    return 'SINO'
  else:
    return False

def is_INTJ(C):
  if re.search('^(E|M)', C):
    return 'INTJ'
  else:
    return False

def is_CC(C):
  if re.search('^(Cp|CONJP)', C):
    return 'CC'
  else:
    return False

def is_MARK(C):
  if C == 'Cs':
    return 'MARK'
  else:
    return False

def is_VOCATIVE(C):
  if '-VOC'in C:
    return 'VOCATIVE'
  else:
    return False

# %% [markdown]
# ##Hàm main

# %%
def get_all_relation(tree):
  tree = from_word_to_number(tree)
  
  result = assign_headword_for_phrase(tree)

  headword_of_phrase = result[0]
  C_of_headword = get_C_of_headword(headword_of_phrase)
  P_of_C = result[1]
  relation_dic = {}
  root_address = C_of_headword[headword_of_phrase['root']]
  
  P_index = '0'
  relation = 'ROOT'
  C_index = headword_of_phrase['root']
  relation_dic[C_index] = [P_index, relation]
  

  for C_index in tree.leaves():
    if C_index not in relation_dic:
      C_address = C_of_headword[C_index]
      if C_address in P_of_C:
        P_address = P_of_C[C_address][0]
        relation = P_of_C[C_address][1]
        P_index = headword_of_phrase[P_address]
        relation_dic[C_index] = [P_index, relation]
      else:
        P_address = get_P_of_C(C_address, root_address)
        P_index = headword_of_phrase[P_address] 
        relation = get_dependency_relation(P_address, C_address, P_index, tree)
        relation_dic[C_index] = [P_index, relation]
  return relation_dic

# %% [markdown]
# #Hậu xử lý

# %% [markdown]
# ## Hàm tạo file thông dụng

# %%
def to_oneline(filename):
  with open(f'/content/{filename}.prd','r',encoding='utf8') as reader:
    regex = r'(?<=<s>).+?(?=</s>)'
    pattern = re.compile(regex,re.M|re.I|re.S)
    data = reader.readlines()
    data = ''.join(data)
    sentences = re.findall(pattern=pattern,string=data)
  with open(f'/content/lines_{filename}.prd','w',encoding='utf8') as writer:
    for sentence in sentences:
      writer.write(re.sub(re.compile('[\s\t\n]+',re.I|re.M),' ',sentence).strip())
      writer.write('\n')

# %% [markdown]
# ## Hàm thông dụng

# %%
# Trả về cây dependency (dạng list)
def get_dependency_tree_list(filename):
  with open(f'/content/lines_{filename}.prd','r',encoding='utf8') as reader:
    lines = reader.readlines()
  dependency_tree_list = []
  for line in lines:
    #print(filename, line)
    dependency_tree = []
    tree = Tree.fromstring(line)
    original_tree = Tree.fromstring(line)
    relations = get_all_relation(tree)
    POS_tags = get_all_POS(tree)
    function_tag_list = get_function_tag(tree)
    for index, word in enumerate(original_tree.leaves()):
      word_index = str(index+1)
      head_index = relations[word_index][0]
      relation = relations[word_index][1]
      POS = POS_tags[index]
      function_tag = function_tag_list[word_index]
      dependency_tree.append([word_index, word, '_', POS, '_', function_tag, head_index, relation,'_','_'])
    dependency_tree_list.append(dependency_tree)
  return dependency_tree_list

# %% [markdown]
# ## Thêm second relation
# + Nguyên nhân: một số nhãn NULL có index refer tới các phrase nên khi khử nhãn NULL -> sửa các relaiton mà chỉ đến  NULL sang chỉ đến phrase mà NULL đề cập tới nhưng làm vậy là sai vì một phrase chỉ được phép nhận 1 head nên việc sửa này được coi là 1 đặc trưng phụ(second relation)
# + Các bước:

# %%
# Lấy các label có index
def get_phrase_contain_index(tree):
  phrase_index_list = []
  phrase_address_list = get_all_subtree_address(tree)
  for phrase_address in phrase_address_list:
    subtree_label = get_subtree(phrase_address, tree).label()
    if re.search('[0-9]$', subtree_label):
      phrase_type = subtree_label.split('-')[0]
      index = subtree_label.split('-')[-1]
      phrase_index = phrase_type + '-' + index
      phrase_index_list.append((phrase_address, phrase_index))

  phrase_index_dic = dict()
  for phrase_index, phrase_address in groupby(sorted(phrase_index_list, key = lambda ele: ele[1]), key = lambda ele: ele[1]):
    phrase_index_dic[phrase_index] = [ele[0] for ele in phrase_address]
  return phrase_index_dic

# %%
# Lấy các vị trí của NULL-word trong câu
def get_phrase_has_linked_NULL(tree):
  word_list = tree.leaves()
  tree = from_word_to_number(tree)
  result = []
  for word, leafPos in zip(word_list, tree.treepositions('leaves')):
    if re.search('^\*', word) and word[-1].isnumeric():
      i = -1
      index_word = tree[leafPos]
      address = leafPos[:i]
      POS = tree[address].label()
      while (POS == 'NONE') or (not POS.isupper()):
        i = i - 1
        address = leafPos[:i]
        POS = tree[address].label()
      phrase_type = POS.split('-')[0]
      NULL_index = word[-1]
      phrase_index = phrase_type + '-' + NULL_index
      result.append([index_word, phrase_index, list(address)])
  return result

# %%
# Trong trường hợp tìm mapping phrase cho NULLword mà có nhiều mapping phrase
# Tính khoảng cách xem NULLword gần với mapping phrase nào nhất?
def get_distance(phrase_address, map_address):
  count = 0
  for phrase_address_index, map_address_index in zip(phrase_address, map_address):
    if phrase_address_index - map_address_index == 0:
      count = count + 1
    else:
      return count

# %%
def find_map_phrase_address(phrase_of_NULL, map_phrase_list):
  map_phrase_exception = {
      'NP':'^(Nc|Ncs|Nu|Nun|Nt|Nq|Num|Nw|Nr|Nn)',
      'VP':'^(Ve|Vc|D|Vcp|Vv)',
      'ADJP':'^(An|Aa)',
      'S':'^SQ'
  }
  phrase_index = phrase_of_NULL[1]
  phrase_address = phrase_of_NULL[2]
  for map_phrase, map_phrase_address in map_phrase_list.items():
    if map_phrase == phrase_index:
      if len(map_phrase_address) >=2:
        distance = []
        for address in map_phrase_address:
          distance.append(get_distance(phrase_address, address))
        selected_index = distance.index(max(distance))
        return map_phrase_address[selected_index]
      else:
        return map_phrase_address[0]
  
  for map_phrase, map_phrase_address in map_phrase_list.items():
    #print(phrase_index)
    phrase_type = phrase_index.split('-')[0]
    index_of_phrase = phrase_index.split('-')[1]
    if re.search(map_phrase_exception[phrase_type], map_phrase) and map_phrase[-1] == index_of_phrase:
      if len(map_phrase_address) >=2:
        distance = []
        for address in map_phrase_address:
          distance.append(get_distance(phrase_address, address))
        selected_index = distance.index(max(distance))
        return map_phrase_address[selected_index]
      else:
        return map_phrase_address[0]
  return False

# %%
def add_second_relation(tree, dependency_tree, linked_NULL_list, map_phrase_list):
  headword_of_phrase = assign_headword_for_phrase(tree)[0]
  for linked_NULL in linked_NULL_list:
    element = dependency_tree[int(linked_NULL[0])-1]
    head_index = element[6]
    relation = element[7]
    map_phrase_address = find_map_phrase_address(linked_NULL, map_phrase_list)
    if map_phrase_address != False:
      map_index = headword_of_phrase[str(map_phrase_address)]
      map_element = dependency_tree[int(map_index)-1]
      second_dep = map_element[8]
      if second_dep == '_':
        map_element[8] = head_index + ':' + relation
      else:
        map_element[8] = map_element[8] + '|' + head_index + ':' + relation
  return dependency_tree

# %%
# Đưa second_relation của NULL lên map phrase
def edit_second_relation_of_NULL(tree, dependency_tree, linked_NULL_list, map_phrase_list):
  headword_of_phrase = assign_headword_for_phrase(tree)[0]
  for linked_NULL in linked_NULL_list:
    element = dependency_tree[int(linked_NULL[0])-1]
    head_index = element[6]
    second_relation = element[8]
    if second_relation != '_':
      map_phrase_address = find_map_phrase_address(linked_NULL, map_phrase_list)
      if map_phrase_address != False:
        map_index = headword_of_phrase[str(map_phrase_address)]
        map_element = dependency_tree[int(map_index)-1]
        second_dep = map_element[8]
        if second_dep == '_':
          map_element[8] = second_relation
        else:
          map_element[8] = map_element[8] + '|' + second_relation
  return dependency_tree

# %% [markdown]
# ## Relink headNULL
# + Nguyên nhân: do khi áp dụng luật chuyển đổi vô tình lấy nhãn NULL làm head

# %%
# Lấy các mối quan hệ mà NULL làm head
def get_dep_dic_of_NULL(dependency_tree):
  dep_dic = {}
  for element in dependency_tree:
    word_index = element[0]
    word = element[1]
    NULL_pos = element[3]
    NULL_head_index = element[6]
    NULL_relation = element[7]
    if re.search('^\*', word):
      dep_index_list = []
      pos_list = []
      word_list = []
      for temp in dependency_tree:
        dep_word_index = temp[0]
        dep_word = temp[1]
        pos_of_dep_word = temp[3]
        head_index = temp[6]
        if head_index == word_index :
          dep_index_list.append(dep_word_index)
          pos_list.append(pos_of_dep_word)
          word_list.append(dep_word)
      if dep_index_list:
        dep_dic[word_index] = [NULL_pos, NULL_head_index, NULL_relation, dep_index_list, pos_list, word_list]
  return dep_dic

# %%
# Chọn một từ mà có mối quan hệ với NULL và trong đó NULL làm head
# Từ được chọn sẽ thay thế NULL làm head cho các mối quan hệ liên quan tới NULL
def select_index(NULL_pos, dep_index_list, pos_list, word_list):
  phrase_type_list = ['^(NP|Nc|Ncs|Nu|Nun|Nt|Nq|Num|Nw|Nr|Nn)', '^(VP|Ve|Vc|D|Vcp|Vv)', '^(ADJP|An|Aa)']
  for phrase_type in phrase_type_list:
    if re.search(phrase_type, NULL_pos):
      for dep_index, pos, word in zip(dep_index_list, pos_list, word_list):
        if (re.search(phrase_type, pos)) and ('*' not in word):
          return dep_index
  for dep_index, pos, word in zip(dep_index_list, pos_list, word_list):
    if (pos != 'PU') and (pos != 'Cp') and (pos != 'Cs') and ('*' not in word):
      return dep_index

  for dep_index, pos, word in zip(dep_index_list, pos_list, word_list):
    if (pos != 'PU') and ('*' not in word):
      return dep_index

# %%
def relink_head_NULL(dependency_tree):
  head_NULL_dic = get_dep_dic_of_NULL(dependency_tree)
  if head_NULL_dic:
    for NULL_index, dep_list in head_NULL_dic.items():
      NULL_pos = dep_list[0]
      NULL_head_index = dep_list[1]
      NULL_relation = dep_list[2]
      dep_index_list = dep_list[3]
      pos_list = dep_list[4]
      word_list = dep_list[5]
      if (len(word_list) == 1) and ('*' not in word_list[0]):
        selected_index = dep_index_list[0]
        selected_element = dependency_tree[int(selected_index)-1]
        selected_element[6] = NULL_head_index
        selected_element[7] = NULL_relation

        for element in dependency_tree:
          second_relation_field = element[8]
          second_relation_list = second_relation_field.split('|')
          second_relation_list = [ selected_index +':'+second_relation.split(':')[1] if second_relation.split(':')[0] == NULL_index else second_relation for second_relation in second_relation_list] 
          element[8] = '|'.join(second_relation_list)

      elif len(word_list) >= 2:
        selected_index = select_index(NULL_pos, dep_index_list, pos_list, word_list)
        selected_element = dependency_tree[int(selected_index)-1]
        selected_element[6] = NULL_head_index
        selected_element[7] = NULL_relation

        for element in dependency_tree:
          head_index = element[6]
          if head_index == NULL_index:
            element[6] = selected_index

          second_relation_field = element[8]
          second_relation_list = second_relation_field.split('|')
          second_relation_list = [ selected_index +':'+second_relation.split(':')[1] if second_relation.split(':')[0] == NULL_index else second_relation for second_relation in second_relation_list] 
          element[8] = '|'.join(second_relation_list)
  return dependency_tree

# %% [markdown]
# ##Khử nhãn NULL

# %%
def minus_1(start_index, end_index):
  minus_1 = {}
  for index in range(start_index, end_index+1):
    minus_1[str(index)]=str(index-1)
  #print(minus_1)
  return minus_1

# %%
def map_index(tree_dependency, minus_1):

  for relation in tree_dependency:
    word_index = relation[0]
    if word_index in minus_1:
      relation[0] = minus_1[word_index]

    head_index = relation[6]
    if head_index in minus_1:
      relation[6] = minus_1[head_index]

    if relation[8] != '_':
      new_second_dependency = []
      second_dependency_element = relation[8]
      second_dependency_list = second_dependency_element.split('|')
      for second_dependency in second_dependency_list:
        split_second_dependency = second_dependency.split(':')
        number = split_second_dependency[0]
        dep = split_second_dependency[1]
        if number in minus_1:
          second_dependency = minus_1[number] +':'+ dep
        new_second_dependency.append(second_dependency)
      relation[8] = '|'.join(new_second_dependency)

  return tree_dependency

# %%
def remove_NULL(tree_dependency):
  #Xóa các second relation mà có head_index trong với head_index chính thức và index_word
  for index, element in enumerate(tree_dependency):
      index_word = index+1
      head_index = element[6]
      second_relation_field = element[8]
      if second_relation_field != '_':
        new_second_relation_list = []
        second_relation_list = second_relation_field.split('|')
        for second_relation in second_relation_list:
          s_head_index = second_relation.split(':')[0]
          if (s_head_index != str(index_word)) and (s_head_index != head_index):
            new_second_relation_list.append(second_relation)
        if new_second_relation_list:
          element[8] = '|'.join(new_second_relation_list)
        else:
          element[8] = '_'

  #Khử nhãn NULL
  check_null_1 = True
  while check_null_1:
    for index, element in enumerate(tree_dependency):
      check_null_2 = True
      word = element[1]
      index_word = index+1

      if re.search('(^\*)', word):
        minus = minus_1(index_word+1, len(tree_dependency))
        tree_dependency = map_index(tree_dependency, minus)
        del tree_dependency[index]
        check_null_2 = False
        break
    if check_null_2:
      check_null_1 = False
  return tree_dependency

# %% [markdown]
# # Tạo file CONLLU

# %%
def finish_dependency_tree(filename, dependency_treebank):
  with open(f'/content/lines_{filename}.prd','r',encoding='utf8') as reader:
    lines = reader.readlines()
  with open(f'/content/[Final]VnDep_{filename}.conllu','w',encoding='utf8') as writer:
    tree_index = 1 
    for line, dependency_tree in zip(lines, dependency_treebank):
      print(filename,line)
      tree = Tree.fromstring(line)
      linked_NULL_list = get_phrase_has_linked_NULL(tree)
      map_phrase_list = get_phrase_contain_index(tree)

      new_dependency_tree = add_second_relation(tree, dependency_tree, linked_NULL_list, map_phrase_list)
      edit_dependency_tree = edit_second_relation_of_NULL(tree, new_dependency_tree, linked_NULL_list, map_phrase_list)
      relink_headNULL_dependency_tree = relink_head_NULL(edit_dependency_tree)
      remove_NULL_dependency_tree = remove_NULL(relink_headNULL_dependency_tree)
      
      writer.write('# ID = {}\n'.format(tree_index))
      tree_index = tree_index + 1
      for element in edit_dependency_tree:
        writer.write('\t'.join(element))
        writer.write('\n')
      writer.write('\n')

# %%
from google.colab import files
file_list = ['Dev_4784','Dev_25432','Dev_25480','Dev_25600','Dev_26554','Dev_46137','Dev_7105','Dev_7276','Dev_81347','Dev_90295','Dev_9539']
dependency_treebank_list = []
for file in file_list:
  to_oneline(file)
  dependency_treebank = get_dependency_tree_list(file)
  finish_dependency_tree(file, dependency_treebank)
# Out:
# Dev_4784 (SPL-HLN (NP (Nn-H Mùi) (NP (Nn-H hổ)) (PP-LOC (Cs-H ở) (NP (Nun-H thành_phố)))) (PU .))
#
# Dev_4784 (S (NP-SBJ (Nn_swsp (Nc-H Người) (Nn đàn_ông)) (VP (Ve-H có) (S-CMP (NP-SBJ (Nq nửa) (Nn-H đời) (NP (Nn-H người))) (VP (Vc-H là) (NP-CMP (Nn-H thợ_săn)))))) (VP (VP (Vv-H vờn) (Vv-H đuổi) (NP-DOB (Vv-H hổ) (ADJP (Aa-H dữ))) (PP-LOC (Cs-H trong) (NP (Nn-H rừng) (Aa rậm)))) (Cp mà) (VP (R không) (Vv-H kinh_sợ))) (PU .))
#
# Dev_4784 (S (S (NP-TMP (Nt-H Nay)) (NP-SBJ (NONE *-1)) (VP (Vv-H làm) (NP-CMP (Nn-H nghề) (VP (VP (Vv-H buôn_bán) (NP-CMP (Nn-H xương) (NP (Nn-H hổ)))) (Cp và) (VP (Vv-H nấu) (NP-CMP (Nn-H cao)) (VP (Vv-H thuê))))) (PP-LOC (Cs-H giữa) (NP (Nun-H thành_phố) (VP (R chỉ) (Ve-H có) (NP (Nn-H con_người) (Cp và) (Nn-H cây_cảnh))))))) (PU ,) (Cp nhưng) (S (NP-SBJ-1 (Pp-H ông)) (VP (VP (R luôn) (Vv-H thấy) (VP-CMP (Vv-H rùng_mình))) (PU ,) (VP (R không) (Vv-H tránh) (R được) (NP-DOB (Nn_swsp (Ncs-H nỗi) (Aa sợ_hãi)))))) (PU ...))
#
# Dev_4784 (SPL-HLN (NP (Nn-H Chợ) (Nn cao)) (PU .))
#
# Dev_4784 (S (S (NP-SBJ (NONE *-1)) (VP-MNR (Vv-H Tàn) (NP (Nn-H rượu) (PP-LOC (Cs-H ở) (NP (Nn-H trang_trại) (NP (Nn-H bác_sĩ) (Nr Dung)))) (NP-TMP (Nt-H hôm) (Pd đó))))) (PU ,) (NP-SBJ-1 (Nn-H đám) (PU ") (Nn cổ_đông) (PU ") (NP (Num bảy) (Nn-H người))) (VP (Vv-H ngồi) (ADJP-MNR (Aa-H tròn)) (PP (Cs-H quanh) (NP (Nn-H chiếu)))) (PU .))
#
# Dev_4784 (S (NP-SBJ (Aa Cả) (Nr-H-1 Tú) (LBRK LBRK) (VP-PRN (Vv-H được) (VP-CMP (Vv-H mời) (NP-SBJ (NONE *D*-1)) (VP (Vv-H đến) (VP (Vv-H chia) (NP-CMP (Nn-H cao)))))) (RBRK RBRK) (S-PRN (NP-SBJ (Nn-H mồm)) (VP (Vv-H ngậm) (ADJP-MNR (Aa-H ngang)) (NP-DOB (Nn-H lưỡi) (NP (Nn-H dao)) (ADJP (ADJP (Aa-H nhọn) (PP (NONE *-1))) (ADJP (Aa-H mỏng_dính) (PP (NONE *-1))) (ADJP (Aa-H bé) (ADJP (Aa-H xíu)) (PP-1 (Cs-H như) (NP (Nn_swsp (Nn-H lá) (Nn lúa)))))))))) (VP (R rón_rén) (Vv-H ướm) (NP-DOB (Nn_swsp (Nc-H cây) (Nn thước)) (NP (Nn-H gỗ))) (PP (Cs-H lên) (NP (Nn-H mặt) (NP (Nn-H mâm)))) (PP (Cs-H như) (VP (Vv-H làm_phép)))) (PU .))
#
# Dev_4784 (S (S (ADJP-ADV (Aa-H Bất_ngờ)) (NP-MNR (Nn_swsp (Nc-H con) (Nn mắt)) (ADJP (Aa-H rực) (R lên))) (PU ,) (NP-SBJ (NONE *-1)) (VP (Vv-H giật) (NP-DOB (Nn-H lưỡi) (NP (Nn-H dao))) (VP (Vv-H đâm) (VP (D-H xuống) (NP (Nn-H mâm)))))) (PU ,) (S (NP-SBJ-1 (Pp-H ông)) (VP (Vv-H cắt) (NP-CMP (Num một) (Nn-H đường) (ADJP (Aa-H thẳng_băng)) (VP (Vv-H theo) (NP-CMP (Nn-H nét) (NP (Nn-H thước))))) (VP (Vv-H chia) (NP-MNR (Nq-H đôi)) (NP-CMP (Nn-H khối) (Nn cao))))) (PU .))
#
# Dev_4784 (S (R Rồi) (PP-ADV (Cs-H như) (VP (Vv-H lên_đồng))) (PU ,) (NP-SBJ (Aa Cả) (Nr-H Tú)) (VP (ADJP (Aa-H liên_tục)) (Vv-H cắt) (NP-MNR (Nn-H ngang_dọc)) (ADJP (Aa-H khắp) (NP (Nn-H mâm)))) (PU .))
#
# Dev_4784 (SPL (VP (R Thật) (Vv-H kinh_ngạc) (SBAR (Cs *0*) (PU ,) (S (NP-SBJ (Num 42) (Nu-H khối)) (ADJP-PRD (ADJP (ID-H vuông_hình_sắc_cạnh)) (ADJP-PRD (R không) (Aa-H hơn) (Aa-H kém) (NP (Nn-H nhau)) (NP (Num 1) (Nu-H gam))))))) (PU .))
#
# Dev_4784 (S (NP-SBJ (Nn-H Bác_sĩ) (Nr Dung)) (VP (Vv-H giở) (NP-DOB (Nn-H sổ)) (VP (Vv-H đọc) (ADJP-MNR (Aa-H to)) (SBAR-CMP (Cs *0*) (PU :) (S (S (NP-SBJ (Nn-H anh) (Nr Kiều)) (NP-PRD (Num 5) (Nu-H lạng))) (PU ,) (S (NP-SBJ (Nn-H bác) (Nr Vui)) (QP-PRD (Num-H 3))) (PU ,) (S (NP-SBJ (Nn-H chị) (Nr Hoa)) (QP-PRD (Num-H 4))))))) (PU ...))
#
# Dev_4784 (S (PP-ADV (Cs-H Sau) (NP (Nq mỗi) (Nn-H câu))) (PU ,) (NP-SBJ (Nn_swsp (Nc-H người) (Nn thanh_niên)) (VP (Ve-H có) (NP (Nn-H ngón) (Nn tay) (ADJP (Aa-H dài) (Aa-H thon))))) (VP (ADJP (Aa-H khéo_léo)) (Vv-H nhét) (NP-DOB (Nq những) (Nn-H miếng) (Nn cao)) (PP (Cs-H vào) (NP (Nn-H túi) (NP (Nn-H nilông)))) (VP (Vv-H buộc) (R lại) (NP (Pp-H từng) (Nn-H phần)) (VP (Vv-H trao) (PP (Cs-H cho) (NP (Nn-H khách)))))) (PU .))
#
# Dev_4784 (S (NP-SBJ (Nn-H Vợ) (NP (Nn-H bác_sĩ) (Nr Dung))) (VP (Vv-H quyết_toán) (SBAR (Cs *0*) (PU :) (S (S (NP-SBJ (Nn-H xương) (NP (Nn-H hổ))) (NP-PRD (Num 12,5) (Nu-H kg) (PU -) (NP-PRN (QP (Num-H 125) (Nq-H triệu)) (Nu-H đồng)))) (PU ,) (S (NP-SBJ (Nn-H xương) (NP (Nn-H gấu))) (NP-PRD (Num 8) (Nu-H kg) (PU -) (QP-PRN (Num-H 4) (Nq-H triệu)))) (PU ,) (S (NP-SBJ (Nn-H xương) (NP (Nn-H sơn_dương))) (NP-PRD (Num 5) (Nu-H kg) (PU -) (NP-PRN (Num 500.000) (Nu-H đồng))))))) (PU .))
#
# Dev_4784 (S (S (NP-SBJ (Nn-H Công) (VP (Vv-H xem) (NP (Nn-H xương)))) (PU :) (QP-PRD (Num-H 3) (Nq-H triệu))) (PU ,) (S (NP-SBJ (Nn-H công) (VP (VP (Vv-H đập) (NP (Nn-H xương))) (Cp và) (VP (Vv-H nấu) (NP (Nn-H cao))))) (QP-PRD (Num-H 5,5) (Nq-H triệu))) (PU ...))
#
# Dev_4784 (S (VP-SBJ (Vv_w (Sv Tổng) (Vv-H cộng))) (NP-PRD (QP (Num-H 150) (Nq-H triệu)) (Nu-H đồng)) (PU .))
#
# Dev_4784 (S (NP-SBJ (Nn-H Giá) (PP (Cs-H tại) (NP (Nn-H nồi)))) (NP-PRD (QP (Num-H 3,34) (Nq-H triệu)) (Nu-H đồng_[]_lạng)) (PU .))
#
# Dev_4784 (S (NP-SBJ (Nw Mọi) (Nn-H người)) (VP (ADJP (Aa-H ồn_ào)) (VP (VP (Vv-H đếm) (NP-DOB (Nn-H tiền))) (PU ,) (VP (Vv-H ký) (NP-DOB (Nn-H sổ))))) (PU ...))
#
# Dev_4784 (S (NP-SBJ (Nn-H Khách) (VP (Vv-H mua) (NP (Nn-H cao)))) (VP (R thường) (Vc-H là) (NP-CMP (Nn-H chỗ) (Vv quen_thân))) (PU .))
#
# Dev_4784 (S (NP-SBJ (ADJP (Aa-H Nhiều)) (Nn-H người)) (VP (Vv-H thuê) (NP-DOB (Nn-H giáo_sư) (PU ,) (Nn-H bác_sĩ) (PU ,) (Nn-H nghệ_nhân)) (VP (Vv-H thẩm_định) (NP-CMP (Nn-H cao)))) (PU .))
#
# Dev_4784 (SPL (VP (Ve-H Có) (S-CMP (NP-SBJ (Nn-H người)) (VP (Vv-H yêu_cầu) (VP-CMP (Vv-H đem) (NP-CMP (Nn-H cao)) (VP (Vv-H đến) (NP (Nn-H Viện) (Nn Công_nghệ_sinh_học)) (VP (Vv-H trưng_cầu) (VP (Vv-H giám_định)))))))) (PU ...))
#
# Dev_4784 (S (NP-SBJ (Nn-H Giá) (VP (Vv-H nấu) (VP (Vv-H thuê))) (NP (QP (QP (Num-H 5)) (PU -) (QP (Num-H 10) (Nq-H triệu))) (Nu-H đồng_[]_nồi))) (VP (Vv-H tuỳ) (PP (Cs-H ở) (UCP (ADJP (Aa-H thân_sơ)) (Cp và) (NP (NP (Nn-H cam_kết) (NP (Nn-H chủ) (Nn-H thợ))))))) (PU .))
#
# Dev_4784 (SPL-HLN (VP (Vv-H Lọc_lừa) (NP (Nn-H hàng_chợ))) (PU .))
#
# Dev_4784 (S (NP-TMP (Nt-H Đêm) (NP (Nt-H 18_-_9))) (PU ,) (S (NP-SBJ (Nn-H lang) (Nr Thưởng)) (VP (R đang) (Vv-H uống) (NP-DOB (Nn-H rượu)) (PP (Cs-H với) (NP (Pp-H tôi))) (PP-LOC (Cs-H ở) (NP (Nr-H Phúc_Yên) (LBRK LBRK) (NP-PRN (Nr-H Mê_Linh) (PU ,) (NP-PRN (Nr-H Vĩnh_Phúc))) (RBRK RBRK))))) (Cp thì) (S (NP-SBJ (Num một) (Nn_swsp (Nc-H chiếc) (Nn xe_hơi))) (VP (Vv-H đón) (VP (Vv-H xuống) (NP-LOC (Nr-H Hà_Nội)) (ADJP-MNR (Aa-H gấp)) (VP (Vv-H xem) (VP (Vv-H giúp)) (NP (Nc-H bộ) (NP (Nn-H xương) (NP (Nn-H hổ))) (VP (PP (Cs-H từ) (NP (Nr-H Ấn_Độ))) (Vv-H về))))))) (PU .))
#
# Dev_4784 (S (NP-SBJ (Nn-H Xe)) (VP (VP (Vv-H vượt) (NP-DOB (Nn-H cầu) (Nr Lủ))) (VP (Vv-H rẽ) (VP-MNR (D-H vào) (NP-LOC (Nn-H khu) (Nn Định_Công) (LBRK LBRK) (NP-PRN (Nr-H Hai_Bà_Trưng)) (RBRK RBRK)))) (VP (Vv-H đến) (NP-CMP (Num một) (Nn-H biệt_thự) (ADJP (Aa-H lớn))))) (PU .))
#
# Dev_4784 (S (NP-SBJ (Nn-H Chủ) (Cp và) (Nn-H khách)) (VP (R đang) (Vv-H đứng) (PP-MNR (Cs-H trước) (NP (Num một) (Nn-H thùng) (NP (Nn-H kim_loại)) (VP (Ve-H có) (NP (Nn-H hệ_thống) (VP (Vv-H giữ) (NP (Nn-H nhiệt))) (ADJP (Aa-H hiện_đại)))) (PU ,) (VP (Vv *P*) (VP-CMP (Vv-H gắn) (NP-DOB (Nn-H nhãn) (NP (Nn-H nước_ngoài)))))))) (PU .))
#
# Dev_4784 (S (NP-SBJ (Nn-H Bên) (Nn trong)) (VP (Vc-H là) (NP-CMP (Num một) (Nn-H khối) (Nn đá) (ADJP (Aa-H lạnh) (Aa-H trong_suốt)) (VP (Vv-H ôm) (ADJP-MNR (Aa-H chặt)) (NP-CMP (Num một) (Nn_swsp (Nc-H con) (Nn hổ)) (NP (NP (Nn-H da) (ADJP (Aa-H vàng) (ADJP (Aa-H vằn_vện))))) (VP (VP (Vv-H bị) (ADJP (Aa-H móp) (PP (Cs-H vào) (NP (Nc-H bộ) (NP (Nn-H xương) (Nn-H thịt)))))) (VP (R đã) (Vv-H móc) (VP (Ve-H hết) (NP (Nn-H ruột_gan))))))))) (PU .))
#
# Dev_4784 (S (NP-SBJ (Nn-H Tay) (PU ") (NP (Nn-H lái) (Nn hổ)) (PU ")) (VP (Vv-H nói) (SBAR-CMP (Cs *0*) (PU :) (PU ") (S (NP-SBJ-1 (Pp-H Nó)) (UCP-PRD (VP (PP (R vừa) (Cs-H từ) (NP (Nn-H chuyên_cơ))) (Vv-H hạ_cánh) (VP (D-H xuống) (NP (Nr-H VN)))) (PU ;) (ADJP (Aa-H nặng) (NP (Num 2,7) (Nu-H tạ)) (LBRK LBRK) (NP-TMP (Nt-H khi) (SBAR (Cs *0*) (S (NP-SBJ (NONE *-1)) (VP (Vv-H sống))))) (RBRK RBRK)) (PU ,) (NP (Nn-H giá) (NP (QP (Num-H 500) (Nq-H triệu)) (Nu-H đồng))))) (PU "))) (PU .))
#
# Dev_4784 (S (NP-SBJ (Nn-H Chủ) (NP (Nn-H nhà)) (PU ,) (NP-PRN (Nn_w (Nn-H viện) (Sv phó)) (NP (Num một) (Nn-H bệnh_viện))) (PU ,)) (VP (VP (Vv-H gật)) (Cp và) (VP (Vv-H đếm) (NP-DOB (Nn-H tiền)))) (PU .))
#
# Dev_4784 (S (NP-SBJ (PU ") (Nn-H Lái) (Nn hổ) (PU ")) (VP (Vv-H dặn) (NP-DOB-1 (Nn-H lang) (Nr Thưởng)) (SBAR-CMP (Cs *0*) (S (NP-SBJ (NONE *-1)) (VP (VP-CND (Vv-H tìm) (NP-DOB (Nn-H khách) (VP (Vv-H mua) (NP (Nn-H xương))))) (Cp thì) (VP (Vv-H được) (VP-CMP (Vv-H hưởng) (QP-DOB (Nq-H triệu)))))))) (PU .))
#
# Dev_4784 (S (Cp Nếu) (S-CND (NP-SBJ (NONE *E*)) (VP (Vv-H lấy) (R ngay))) (PU ,) (S (NP-SBJ (Pp-H hắn)) (VP (R chỉ) (Ve-H còn) (NP-CMP (Num ba) (Nn-H bộ) (NP (QP (Num-H 5) (PU ,) (Num-H 7) (Cp và) (Num-H 8)) (Nu-H kg))))) (PU .))
#
# Dev_4784 (S (NP-SBJ (Nn-H Giá) (NP (Nn-H xương) (ADJP (Aa-H to) (Aa-H nhỏ)))) (ADJP-PRD (Aa-H chênh) (NP (Nn-H nhau)) (NP (Nq 2_triệu_[]_kg))) (PU .))
#
# Dev_4784 (S (NP-SBJ (Nn-H Lang) (Nr Thưởng)) (VP (Vv-H cho) (NP-IOB (NONE *E*)) (VP-CMP (Vv-H hay) (SBAR-CMP (Cs *0*) (PU :) (S (NP-TMP (Nt-H hiện)) (PP-LOC (Cs-H ở) (NP (Nr-H Hà_Nội))) (NP-SBJ (Pp-H ông)) (NP (ADJP (Aa-H có_thể)) (Vv-H mua) (NP-DOB (Nn-H xương) (NP (Nn-H hổ))) (NP-TMP (R bất_cứ) (Nt lúc) (Pd nào) (PP (Cs-H sau) (NP (Num ba) (Nu-H giờ) (Vv hẹn))))))))) (PU .))
#
# Dev_4784 (S (NP-SBJ (NONE *E*)) (VP (VP-CND (Vv-H Muốn) (NP-DOB (Nn-H hổ) (ADJP (Aa-H tươi)))) (Cp thì) (VP (Vv-H đợi) (NP-TMP (Nq vài) (Nu-H tuần)))) (PU .))
#
# Dev_4784 (S (NP-TPC-1 (Nq Các) (Nn-H phương_tiện) (Vv vận_chuyển)) (NP-SBJ (Nw-H hầu_hết) (NP (NONE *T*-1))) (VP (Vc-H là) (UCP-CMP (ADJP (Aa-H đặc_chủng)) (Cp hoặc) (NP (Nn-H giấy_phép) (Aa đặc_biệt)))) (PU .))
#
# Dev_4784 (S (NP-SBJ (Nn-H Hổ) (Pd này)) (VP (Vc-H là) (PP-CMP (Cs-H của) (NP (Nr-H Ấn_Độ) (PU ,) (Nr-H Bangladesh) (PU ,) (Nr-H Sri_Lanka) (PU ,) (Nr-H Nga) (PU ,) (Nr-H Thái_Lan)))) (PU ...))
#
# Dev_4784 (S (NP-SBJ (Nn-H Đường) (NP (Nn-H thứ) (An ba))) (VP (Vc-H là) (VP (PP-MNR (Cs-H từ) (NP (Nr-H Campuchia) (PU ,) (Nr-H Lào))) (Vv-H về) (PP-MNR (Cs-H qua) (NP (Nq các) (Nn-H cửa_khẩu) (NP-LOC (NP (Nn-H Cầu_Treo) (LBRK LBRK) (NP-PRN (Nr-H Hà_Tĩnh)) (RBRK RBRK)) (Cp và) (NP (Nr-H Lai_Châu))))))) (PU .))
#
# Dev_4784 (S (VP-TMP (Vv-H Cách) (NP (Pd-H đây)) (NP (Nq-H vài) (Nu-H năm))) (PU ,) (NP-SBJ (Nn-H lực_lượng) (NA an_ninh) (NP-LOC (Nr-H Ninh_Bình))) (VP (Vv-H bắt) (R được) (NP-DOB (Num một) (Nn-H vụ) (VP (Vv-H buôn_bán) (NP-DOB (QP (R gần) (Num-H 30)) (Nn_swsp (Nc-H bộ) (NP (Nn-H xương) (NP (Nn-H hổ)))))))) (PU .))
#
# Dev_4784 (S (Cp Nhưng) (NP-TMP (Nt-H khi) (SBAR (Cs *0*) (S (NP-SBJ (NONE *E*)) (VP (Vv-H kiểm_tra))))) (Cp thì) (NP-SBJ (NONE *E*)) (VP (R toàn) (Vc-H là) (PU ...) (NP-CMP (Nn-H bột) (NP (Nn-H ximăng)))) (PU .))
#
# Dev_4784 (S (NP-SBJ (Nn-H Hàng) (Aa giả) (ADJP-SBJ (Aa-H độc) (R nhất))) (VP (Vc-H là) (VP-CMP (Vv-H làm) (NP (Nn-H xương) (NP (Nn-H hổ))) (PP-MNR (Cs-H bằng) (NP (Nn-H bột) (NP (Nn-H ximăng) (PU ,) (Nn-H thạch_cao)))) (PP (Cs-H với) (S (NP-SBJ-1 (NP (Nq những) (Nn-H đường_nét) (PU ,) (Nn-H hoa_văn) (PU ,) (Nn-H trọng_lượng)) (PU ,) (NP (R thậm_chí) (M cả) (NP (NP (Nn-H khuyết_tật)) (PU ,) (NP (Nn-H vết) (Vv trúng_thương)) (Cp hay) (NP (Nn-H đặc_điểm) (VP (Vv-H sống) (PP-LOC (Cs-H ở) (NP (Nq các) (Nn-H vùng)))))))) (VP (R cũng) (Vv-H được) (S-CMP (NP-SBJ (Nq các) (PU ") (Nn-H nghệ_sĩ) (Nn điêu_khắc) (PU ")) (VP (Vv-H phù_phép) (NP-DOB (NONE *T*-1)) (PP (Cs-H như) (ADJP (Aa-H thật)))))))))) (PU .))
#
# Dev_4784 (S (VP-SBJ (Vv-H Lừa) (ADJP (Aa-H thông_thường))) (VP (Vc-H là) (VP-CMP (Vv-H tráo) (PP-MNR (Cs-H bằng) (NP (NP (Nn-H xương) (NP (Nn-H gấu))) (PU ,) (NP (Nn-H xương) (NP (Nn-H báo))) (PU ,) (NP (Nn-H xương) (NP (Nn-H ngựa))))))) (PU .))
#
# Dev_4784 (S (S (VP-SBJ (Ve-H Có) (NP (PU ") (Nn-H tâm) (PU ")) (R hơn)) (VP (Vc-H là) (VP-CMP (Vv-H trộn) (NP (Nn-H xương) (Aa khác))))) (Cp và) (S (ADJP-SBJ (PU ") (Aa-H tử_tế) (PU ") (R nhất)) (VP (Vc-H là) (VP-CMP (VP (Vv-H bớt) (R đi) (NP (Num một_số) (Nn-H xương) (ADJP (Aa-H quan_trọng)))) (Cp hoặc) (VP (Vv-H gắn) (VP (Vv-H thêm)) (NP (Nn-H thịt)) (PP (Cs-H vào)) (PP-PRP (Cs-H cho) (ADJP (Aa-H nặng))))))) (PU ...))
#
# Dev_4784 (S (VP-SBJ (Vv-H Lừa) (NP (Nn-H cấp) (ADJP (Aa-H thấp) (R hơn)))) (VP (Vc-H là) (S-CMP (NP-TMP (Nt-H khi) (SBAR (Cs *0*) (S (NP-SBJ (NONE *E*)) (VP (Vv-H nấu) (NP-DOB (Nn-H cao)))))) (NP-SBJ (NONE *E*)) (VP (Vv-H lấy) (VP-MNR (Vv-H trộm)) (NP-DOB (Nn-H dịch) (Vv chiết)) (PU ,) (VP (Vv-H pha) (VP (Vv-H thêm)) (NP-DOB (Nq các) (Nn-H xương) (NP (Nn-H trâu) (PU ,) (Nn-H mèo) (PU ,) (Nn-H chó) (PU ,) (Nn-H gấu))))))) (PU ...))
#
# Dev_4784 (S-HLN (NP-SBJ (Nn_swsp (Ncs-H Sự) (Vv quản_lý))) (ADJP-PRD (PU ") (Aa-H mềm_yếu) (PU ")) (PU .))
#
# Dev_4784 (S (NP-SBJ (Nn-H Ông) (Nr Nguyễn_Bá_Thụ) (PU ,) (NP-PRN (Nn_w (Nn-H cục) (Sv trưởng)) (NP (Nn-H Cục) (Vv Kiểm_lâm) (NP-LOC (Nr-H VN)))) (PU ,)) (VP (Vv-H thừa_nhận) (SBAR-CMP (Cs *0*) (S (NP-SBJ (Nn-H tình_trạng) (VP (Vv-H vận_chuyển) (PU ,) (Vv-H buôn_bán) (NP-DOB (NP (Nn-H hổ)) (Cp và) (NP (Nn-H xương) (NP (Nn-H hổ)))) (ADJP-MNR (Aa-H trái_phép)))) (VP (VP (RP (R vẫn) (R-H đang)) (Vv-H diễn) (R ra) (PP-LOC (Cs-H tại) (NP (Nr-H VN)))) (Cp và) (VP (ADJP (Aa-H đặc_biệt)) (Vv-H sôi_động) (PP-LOC (Cs-H ở) (NP (Nr-H Hà_Nội)))))))) (PU .))
#
# Dev_4784 (S (UCP-ADV (PP (Cs-H Với) (NP (Nq những) (Nn-H hình_thức) (Vv che_giấu) (ADJP (Aa-H tinh_vi)))) (Cp và) (VP (Ve-H có) (NP (M cả) (Nn_swsp (Ncs-H sự) (Vv bảo_kê))))) (Cp thì) (NP-SBJ-1 (Nn-H kiểm_lâm)) (PP (R gần) (Cs-H như) (VP (Vv-H bị) (VP-CMP (Vv-H đẩy) (NP-DOB (NONE *T*-1)) (R ra) (PP (Cs-H ngoài) (NP (Nn-H cuộc)))))) (PU .))
#
# Dev_4784 (S (NP-SBJ (Nn-H Ông) (Nr Nguyễn_Công_Đức) (PU ,) (NP-PRN (Nn_w (Nn-H chi_cục) (Nn trưởng)) (NP (Nn-H Chi_cục) (Vv Kiểm_lâm) (NP-LOC (Nr-H Hà_Nội)))) (PU ,)) (VP (Vv-H cho) (NP-IOB (NONE *E*)) (VP-CMP (Vv-H biết) (SBAR-CMP (Cs *0*) (PU :) (S (NP-TMP (Nt-H tháng) (Nt 9_–_2003)) (NP-SBJ (Nn-H chi_cục)) (VP (VP (Vv-H truy_quét) (NP-DOB (Nw toàn) (Nun-H thành_phố))) (PU ,) (VP (Vv-H thu_giữ) (R được) (NP-DOB (Num bảy) (Nn_swsp (Nc-H bộ) (Nn da)) (NP (Nn-H hổ)) (Vv nhồi))) (Cp và) (VP (Vv-H đưa) (VP-CMP (Vv-H về) (NP-CMP (Nn-H Trung_tâm) (VP (Vv-H Cứu_hộ) (NP (Nn-H động_vật) (Aa hoang_dã))) (PP-LOC (Cs-H ở) (NP (Nr-H Sóc_Sơn))))))))))) (PU .))
#
# Dev_4784 (S (Cp Nhưng) (Cp do) (S-PRP (NP-SBJ (R không) (Pp-H ai)) (VP (Vv-H xác_định) (R được) (SBAR-CMP (Cs *0*) (S (NP-SBJ (Nq những) (Nn_swsp (Nc-H con) (Nn hổ)) (Pd này)) (VP (Vv-H chết) (PP-TMP (Cs-H từ) (NP (Pp-H bao_giờ)))))))) (Cp nên) (S (NP-TMP (Nt-H khi) (SBAR (Cs *0*) (S (NP-SBJ (Pp-H tôi)) (ADJP-PRD (Aa-H có_mặt) (PP-LOC (Cs-H ở) (NP (Nn-H trung_tâm) (Pd này))))))) (PU ,) (NP-SBJ (Nq các) (Nn-H chủ_nhân) (PP (Cs-H của) (NP (Pp-H nó)))) (VP (R đã) (Vv-H đòi) (VP-CMP (Vv-H về)) (VP (R gần) (Ve-H hết)) (SBAR-PRP (Cs vì) (S (NP-SBJ (Pp-H họ)) (VP (Vv-H bảo) (SBAR-CMP (Cs *0*) (S (NP-SBJ (Pd-H đó)) (VP (Vc-H là) (NP-CMP (Nn-H đồ) (NP (Nn-H gia_bảo) (VP (Vv-H để) (R lại)))))))))))) (PU .))
#
# Dev_4784 (SPL-HLN (NP (Nn-H Tiệc) (VP (Vv-H tráng) (NP (Nn-H chảo)))) (PU .))
#
# Dev_4784 (S (NP-SBJ (Nn-H Rượu_mạnh) (VP (Nn-H pha) (NP (Nn-H cao) (NP (Nn-H hổ))))) (VP (Vv-H làm) (S-CMP (NP-SBJ (Nq những) (Nn-H tròng) (NP (Nn-H mắt)) (ADJP (Aa-H đỏ_rực))) (VP (Vv-H vằn) (R lên) (PP (Cs-H dưới) (NP (Nn_swsp (Nc-H ánh) (Nn lửa))))))) (PU .))
#
# Dev_4784 (S (NP-SBJ (Nq Những) (Nn-H quan_khách) (ADJP (Aa-H lịch_lãm)) (Pd ấy)) (VP (Vv-H ngửa) (NP-DOB (Nn-H mặt)) (VP (Vv-H cười) (ADJP-CMP (Aa-H đầy) (VP (Vv-H mãn_nguyện))))) (PU .))
#
# Dev_4784 (S (R Hình_như) (S (NP-SBJ-1 (Pp-H tôi)) (ADJP-PRD (Vv-H say))) (Cp nên) (S (NP (NONE *T*-1)) (VP (R cứ) (Vv-H thấy) (SBAR-CMP (Cs *0*) (S (ADJP-TPC-1 (Aa-H rần_rật) (PP (Cs-H trong) (NP (Nn-H huyết_quản) (NP (Pp-H mình))))) (NP-SBJ (Nq những) (Nn-H dòng) (Nn máu) (ADJP (Aa-H lạ))) (ADJP-PRD (NONE *T*-1)))))) (PU .))
#
# Dev_4784 (S (NP-SBJ (Nn-H Lang) (Nr Thưởng)) (VP (Vv-H nói) (SBAR-CMP (Cs *0*) (PU :) (PU ") (S (S (NP-SBJ (NONE *E*)) (VP (Vv-H Đừng) (VP-CMP (Vv-H sợ)))) (PU ,) (SPL (SPL (PP-ADV (Cs-H trong) (NP (Nn-H cơ_thể) (PP (Cs-H của) (NP (Nun-H thành_phố))))) (VP (RP (R cũng) (R-H đang)) (Ve-H có) (S-CMP (NP-SBJ (Nq những) (Nn-H mạch_máu) (NP (Nn-H hổ))) (VP (Vv-H len_lỏi) (VP (Vv-H chảy) (VP (Vv-H nuôi) (NP-DOB (Nq những) (PU ") (Nn-H tế_bào) (Nn quí_tộc) (PU ")))))))) (Cp mà) (SPL (VP (Ve-H có) (NP-CMP (Pp-H sao) (M đâu)))))) (PU "))) (PU ...))
#
# Dev_25432 (S-HLN (NP-PRN-LOC (Nr-H Phú_Yên)) (PU :) (S (NP-SBJ (Nn-H cán_bộ)) (VP (Vv-H làm) (ADJP (Aa-H sai)))) (PU ,) (S (NP-SBJ (Nn-H dân)) (VP (Vv-H lãnh) (ADJP (Aa-H đủ)))) (PU .))
#
# Dev_25432 (S (NP-SBJ (QP (R Hàng) (Nq-H trăm)) (Nn-H hộ) (Nn dân) (NP-LOC (Nr-H Phú_Yên))) (VP (R vừa) (Vv-H nhận) (M được) (NP-DOB (Nn-H thông_báo) (VP (Vv-H trả) (R lại) (NP (Nn-H tiền) (VP (Vv-H sử_dụng) (NP (Num 350) (Nu-H ha) (Nn đất) (VP (R đã) (Vv-H cấp) (NP (Nn-H sổ_đỏ))) (PP-LOC (Cs-H ở) (NP (Nq các) (Nun-H khu) (Nn dân_cư) (Aa mới) (NP (Nun-H xã) (Nr Xuân_Hải) (PU ,) (NP-PRN (Nr-H Sông_Cầu))))))))))) (PU .))
#
# Dev_25432 (S (VP-TMP (Vv-H Cách) (NP (Pd-H đây)) (NP (QP (R hơn) (Num-H ba)) (Nu-H năm)) (PU ,) (PP-PRN (Cs-H vào) (NP (R khoảng) (Nt-H tháng) (NP (Num-H 10) (PU ,) (Nt-H 11_-_2000)) (PU ,) (NP-PRN (Nt-H khi) (SBAR (Cs *0*) (S (NP-SBJ (Nn_swsp (Nc-H con) (Nn đường)) (NP (Nr-H Qui_Nhơn) (PU -) (Nr-H Sông_Cầu))) (VP (R vừa) (Vv-H bắt_đầu) (VP-CMP (VP (Vv-H manh_nha)) (Vv-H hình_thành)))))))) (PU ,)) (NP-SBJ (ADJP (Aa-H nhiều)) (Nn-H người)) (VP (Ve-H có) (NP-CMP (Nn-H thông_tin) (ADJP (Aa-H sớm) (R nhất)) (PP (Cs-H về) (NP (Nn-H việc) (VP (Vv-H giao) (NP (Nn-H đất) (Vv ở) (PP-LOC (Cs-H tại) (NP (Nun-H khu) (Vv qui_hoạch) (Nn dân_cư) (Aa mới) (PP (Cs-H tại) (NP (Nun-H xã) (Nr Xuân_Hải) (PU ,) (NP-PRN (Nun-H huyện) (Nr Sông_Cầu) (PU ,) (NP-PRN (Nun-H tỉnh) (Nr Phú_Yên))))))))))))) (PU .))
#
# Dev_25432 (S (NP-SBJ (Pp-H Họ)) (VP (R lập_tức) (Vv-H thông_báo) (PP-IOB (Cs-H với) (NP (Nn-H người_thân) (Cp và) (Nn-H bạn_bè))) (VP-CMP (Vv-H đến) (VP (Vv-H nộp) (NP-DOB (Nn-H đơn) (VP (Vv-H xin) (VP-CMP (Vv-H mua) (NP-DOB (Nn-H đất) (Vv xây_dựng)))))))) (PU .))
#
# Dev_25432 (S (PP-TMP (R Chỉ) (Cs-H trong) (NP (Num một) (Nn-H thời_gian) (ADJP (Aa-H ngắn)))) (PU ,) (NP-SBJ-1 (QP (R hàng) (Nq-H trăm)) (Nn-H hồ_sơ) (VP (Vv-H xin) (VP (Vv-H giao) (LBRK LBRK) (VP-PRN (Vv-H mua)) (RBRK RBRK) (NP-DOB (Nn-H đất)))) (PP (Cs-H của) (NP (Nn_swsp (Nc-H người) (Nn dân)) (PP-LOC (Cs-H từ) (NP (NP (Nun-H thành_phố) (Nr Qui_Nhơn) (LBRK LBRK) (NP-PRN (Nr-H Bình_Định)) (RBRK RBRK)) (Cp và) (NP (Nun-H huyện) (Nr Sông_Cầu) (LBRK LBRK) (NP-PRN (Nr-H Phú_Yên)) (RBRK RBRK))))))) (VP (R đã) (Vv-H được) (S-CMP (NP-SBJ (X-H UBND) (NP (Nun-H huyện) (Nr Sông_Cầu))) (VP (VP (Vv-H xem_xét) (NP-DOB (NONE *T*-1))) (Cp và) (VP (Vv-H ra) (NP-DOB (Nn-H quyết_định) (VP (Vv-H cấp) (NP-DOB (Nn-H đất)) (VP-MNR (Vv-H theo) (NP (Nn-H quyết_định) (NP (Nn-H số) (Nr 2554_[]_QĐ_-_UB)) (NP-TMP (Nt-H ngày) (Nt 5_-_10_–_2000)) (PP (Cs-H của) (NP (X-H UBND) (NP (Nun-H tỉnh) (Nr Phú_Yên)))))))))))) (PU .))
#
# Dev_25432 (S (S (NP-SBJ-1 (Nn-H Thủ_tục) (ADJP (Aa-H quan_trọng) (R nhất))) (VP (R cũng) (Vv-H được) (VP-CMP (Vv-H hoàn_tất) (NP-DOB (NONE *T*-1))))) (PU ,) (S-PRN (NP-SBJ (Pd-H đó)) (VP (Vc-H là) (S-CMP (NP-SBJ-3 (Nn-H-2 giấy) (VP (Vv-H chứng_nhận) (NP (Nn-H quyền) (VP (Vv-H sử_dụng) (NP (Nn-H đất))))) (PU ,) (VP-PRN (R còn) (Vv *P*) (VP-CMP (Vv-H gọi) (NP-DOB (Nn-H *D*-2)) (PP-CMP (Cs-H là) (NP (Nn-H sổ_đỏ))))) (PU ,)) (VP (R đã) (Vv-H được) (S-CMP (NP-SBJ (X-H UBND) (NP (Nun-H huyện) (Nr Sông_Cầu))) (VP (Vv-H cấp) (NP-DOB (NONE *T*-3)))))))) (PU .))
#
# Dev_25432 (S (NP-SBJ (NONE *E*)) (VP (Vv-H Được) (VP-CMP (Vv-H biết) (SBAR-CMP (Cs *0*) (PU ,) (S (NP-SBJ-1 (Nn-H dự_án) (VP (Vv-H qui_hoạch) (Vv-H phát_triển) (NP (Nn-H khu) (Nn dân_cư) (Aa mới) (PP-LOC (Cs-H tại) (NP (Nun-H xã) (Nr Xuân_Hải)))))) (VP (Vv-H được) (VP-CMP (Vv-H đầu_tư) (NP-DOB (NONE *T*-1)) (VP-MNR (Vv-H theo) (NP (Nn-H phương_thức) (VP (Vv-H chuyển_giao) (NP (Nn-H quyền) (VP (Vv-H sử_dụng) (NP (Nn-H đất) (VP (Vv-H xây_dựng) (NP (Nn-H nhà) (Vv ở))))))))))))))) (PU .))
#
# Dev_25432 (S (NP-SBJ (Nn-H Thực_chất)) (VP (Vc-H là) (VP-CMP (Vv-H đổi) (NP-DOB (Nn-H đất)) (VP (Vv-H lấy) (NP-CMP (Nn-H hạ_tầng))))) (PU .))
#
# Dev_25432 (S (NP-SBJ-1 (Nn-H Dự_án) (Pd này)) (VP (R đã) (Vv-H được) (S-CMP (NP-SBJ (X-H UBND) (NP (Nun-H tỉnh) (Nr Phú_Yên))) (VP (VP (Vv-H phê_duyệt) (NP-DOB (NONE *T*-1))) (Cp và) (VP (Vv-H giao) (NP-DOB (NONE *T*-1)) (PP-PRP (Cs-H cho) (S (NP-SBJ (X-H UBND) (NP (Nun-H huyện) (Nr Sông_Cầu))) (VP (Vv-H thực_hiện)))))))) (PU .))
#
# Dev_25432 (S (S (NP-SBJ-1 (Nn-H Sơ_đồ) (Vv qui_hoạch)) (VP (Vv-H được) (S-CMP (NP-SBJ (Nn-H chính_quyền) (Aa sở_tại)) (VP (Vv-H công_bố) (NP-DOB (NONE *T*-1)) (ADJP (Aa-H công_khai)))))) (PU ,) (S (NP-TMP (Nt-H hiện)) (NP-SBJ-2 (NONE *-1)) (VP (R vẫn) (Vv-H được) (VP-CMP (Vv-H dựng) (NP-DOB (NONE *T*-2)) (ADJP (Aa-H công_khai)) (VP-LOC (Vv-H cách) (NP (Nn-H trụ_sở) (NP (X-H UBND) (NP (Nun-H xã) (Nr Xuân_Hải)))) (NP (QP (R khoảng) (Num-H 2)) (Nu-H km)))))) (PU .))
#
# Dev_25432 (S (PP-TMP (Cs-H Sau) (NP (Nt-H khi) (SBAR (Cs *0*) (S (NP-SBJ (NONE *E*)) (VP (Vv-H hoàn_tất) (NP-DOB (Nn-H thủ_tục))))))) (PU ,) (NP-TMP (Nn-H thời_gian) (Aa qua)) (NP-SBJ (Nq một_số) (Nn-H chủ) (VP (Vv-H sở_hữu) (NP (Nn-H đất) (Vv ở)))) (VP (R đã) (Vv-H đầu_tư) (VP (Vv-H thuê) (VP-CMP (Vv-H nâng_cấp) (NP-DOB (Nn-H mặt_bằng) (VP (Vv-H xây_dựng) (NP (Nn-H nền_móng))))))) (PU .))
#
# Dev_25432 (S (S (NP-SBJ-1 (Nq Một_số) (Nn-H người)) (VP (R đã) (Vv-H xin) (R được) (NP-DOB (Nn-H giấy_phép) (NP (X-H UBND) (NP (Nun-H xã) (Nr Xuân_Hải))) (PP-PRP (Cs-H để) (VP (Vv-H đổ) (NP-DOB (Nn-H đất)) (VP (Vv-H nâng) (NP (Nn-H mặt_bằng)))))))) (PU ,) (Cp nhưng) (S (NP-TMP (Nt-H khi) (SBAR (Cs *0*) (S (NP-SBJ (NONE *-1)) (VP (Vv-H tiến_hành))))) (Cp thì) (NP-SBJ-2 (NONE *-1)) (VP (Vv-H bị) (S-CMP (NP-SBJ (Nn-H cư_dân) (PP (Cs-H ở) (NP (Nn-H địa_phương)))) (VP (Vv-H ngăn_cản) (NP-DOB (NONE *T*-2)) (ADJP (Aa-H quyết_liệt)))))) (PU .))
#
# Dev_25432 (S (Cp Còn) (NP-SBJ-1 (X-H UBND) (NP-LOC (Nun-H huyện) (Nr Sông_Cầu))) (VP (VP (RP (R lại) (R-H không)) (Vv-H trả_lời) (ADJP (Aa-H dứt_khoát))) (PU ,) (VP (R cứ) (ID-H hẹn_lần_hẹn_lữa) (PP (Cs-H về) (NP (Nn-H việc) (SBAR (Cs *0*) (S (NP-SBJ (NONE *-1)) (VP (R sẽ) (Vv-H cấp) (NP-DOB (Nn-H giấy_phép) (VP (Vv-H xây_dựng) (NP (Nn-H nhà) (Vv ở)))) (PP-IOB (Cs-H cho) (NP (Nq những) (Nn-H người) (VP (R đã) (Vv-H được) (VP-CMP (Vv-H cấp) (NP-DOB (Nn-H đất))))))))))))) (PU .))
#
# Dev_25432 (S (PP-TMP (Cs-H Đến) (NP (Nt-H ngày) (Nt 11_-_1_–_2003))) (PU ,) (NP-SBJ-1 (Nq các) (Nn-H hộ) (VP (Vv-H mua) (NP (Nn-H đất) (PP-LOC (Cs-H ở) (NP (Nun-H khu) (Nn dân_cư) (Aa mới) (Nr Xuân_Hải)))))) (VP (ADJP (Aa-H đột_ngột)) (Vv-H bị) (VP-CMP (Vv-H mời) (NP-DOB (NONE *T*-1)) (VP (Vv-H về) (NP (Nun-H huyện) (Nr Sông_Cầu)) (PP-PRP (Cs-H để) (VP (Vv-H nghe) (VP-CMP (Vv-H phổ_biến) (NP-DOB (Nn-H chủ_trương) (PP (Cs-H của) (NP (X-H UBND) (NP (Nun-H tỉnh) (Nr Phú_Yên)))) (PU ,) (VP-PRN (Vv-H thu_hồi) (NP-DOB (Nn-H đất)) (PP-IOB (Cs-H đối_với) (NP (Nq các) (Nn-H hộ) (Nn dân) (VP (R không) (Vv-H thường_trú) (PP-LOC (Cs-H tại) (NP (Nun-H xã) (Nr Xuân_Hải)))))))))))))) (PU .))
#
# Dev_25432 (S (PP-TMP (Cs-H Trong) (NP (Nt-H lúc) (SBAR (Cs *0*) (S (NP-SBJ (ADJP (Aa-H nhiều)) (Nn-H công_dân) (VP (Ve-H có) (NP-CMP (Nn-H đất) (PP-LOC (Cs-H tại) (NP (Nn-H khu) (Nn dân_cư) (Aa mới) (Nr Xuân_Hải)))))) (UCP-PRD (ADJP (Aa-H bất_ngờ)) (VP (R không) (Vv-H hiểu) (SBAR (Cs *0*) (S (NP-SBJ (Nn-H chuyện) (Pp gì)) (VP (R đang) (Vv-H xảy_ra)))))))))) (Cp thì) (VP-TMP (Vv-H tiếp) (NP (Pd đó))) (NP-SBJ (Pp-H họ)) (VP (R lại) (Vv-H nhận) (M được) (NP-DOB (Nn-H giấy) (Vv thông_báo) (PP (Cs-H của) (NP-1 (Nn-H Phòng) (NP (Nn-H Tài_chính) (PU -) (Nn-H kế_hoạch)) (NP (Nun-H huyện) (Nr Sông_Cầu)))) (PP (Cs-H về) (NP (Nn-H việc) (SBAR (Cs *0*) (S (NP-SBJ (NONE *-1)) (VP (Vv-H trả) (R lại) (NP-DOB (Nn-H-2 tiền) (VP (Vv-H sử_dụng) (NP (Nn-H đất))) (PU ,) (VP-PRN (R có) (Vv-H được) (VP-CMP (Vv-H cộng) (NP-DOB (Nn-H *D*-2)) (PP (Cs-H với) (NP (Nn-H lãi_suất) (PP (Cs-H của) (NP (Nn-H ngân_hàng))) (VP-MNR (Vv-H theo) (NP (Nt-H thời_điểm) (SBAR (Cs *0*) (S (NP-SBJ (NONE *-1)) (VP (Vv-H nộp) (NP (Nn-H tiền))))))))))))))))))) (PU .))
#
# Dev_25432 (S (NP-SBJ-1 (Nn-H Lý_do)) (VP (Vv-H được) (S (NP-SBJ-2 (Nn-H phía) (Nn chính_quyền) (NP (Nun-H tỉnh) (Nr Phú_Yên))) (VP (Vv-H thông_báo) (NP (NONE *T*-1)) (NP (Nn-H một_cách) (ADJP (R khá) (Aa-H lạnh_lùng))) (SBAR-CMP (Cs *0*) (PU :) (S (NP-SBJ (NONE *-2)) (VP (Vv-H thực_hiện) (NP-MNR (Nn-H thông_báo) (Nr 904_[]_TB_-_UB) (NP-TMP (Nt-H ngày) (Nt 15_-_12_–_2003)) (PP (Cs-H của) (NP (X-H UBND) (NP (Nun-H tỉnh) (Nr Phú_Yên)))) (SBAR (Cs là) (S (NP-SBJ (NONE *-2)) (VP (Vv-H phải) (VP-CMP (Vv-H thu_hồi) (NP-DOB (Nn-H đất) (PP (Cs-H của) (NP (Nq các) (Nn-H hộ) (Nn dân) (PP-LOC (Cs-H ngoài) (NP (Nun-H xã) (Nr Xuân_Hải))))))))))))))))) (PU .))
#
# Dev_25432 (S (NP-SBJ (Nn-H-1 Sự_việc) (VP (Vv *P*) (VP-CMP (Vv-H nói) (NP-DOB (Nn *D*-1)) (NP (Nn-H trên))))) (VP (VP (R đã) (Vv-H gây) (ADJP-CMP (Aa_w (Sv bất) (Aa-H bình))) (PP-IOB (Cs-H cho) (NP (QP (R hàng) (Nq-H trăm)) (Nn-H hộ) (Nn dân) (VP (Ve-H có) (NP-CMP (Nn-H-2 đất) (Vv ở) (VP (Vv *P*) (VP-CMP (Vv-H mua) (NP-DOB (Nn-H *D*-2)) (PP-LOC (Cs-H tại) (NP (Nn-H khu) (Nn dân_cư) (Aa mới) (Nr Xuân_Hải)))))))))) (PU ,) (VP (Vv-H gây_nên) (VP-CMP (Vv-H kiện_cáo) (VP (Vv-H kéo) (ADJP (Aa-H dài)))))) (PU .))
#
# Dev_25432 (S (S (NP-SBJ (NONE *-1)) (VP-MNR (Vv-H Trao_đổi) (PP (Cs-H với) (NP (Nn-H Tuổi_Trẻ))))) (PU ,) (NP-SBJ-1 (Nn-H ông) (Nr Đào_Tấn_Lộc) (PU ,) (NP-PRN (Nn-H chủ_tịch) (NP (X-H UBND) (NP (Nun-H tỉnh) (Nr Phú_Yên)))) (PU ,)) (VP (Vv-H khẳng_định) (SBAR-CMP (Cs *0*) (S (S (NP-SBJ (Pd-H đây)) (VP (Vc-H là) (NP-CMP (Nn-H việc_làm) (ADJP (Aa-H sai_trái)) (PP (Cs-H của) (NP (Nn-H chính_quyền) (NP (Nun-H huyện) (Nr Sông_Cầu))))))) (PU ,) (S (NP-SBJ (Nn-H vụ_việc) (Pd này)) (VP (R đã) (Vv-H khiến) (SBAR-CMP (Cs *0*) (S (S (NP-SBJ (Num một) (Nn-H chủ_tịch) (NP (Nun-H huyện))) (VP (Vv-H bị) (VP-CMP (Vv-H thuyên_chuyển) (NP-DOB (Nn-H công_tác))))) (Cp và) (S (NP-SBJ-1 (NP (Num một) (Nn_w (Sv phó) (Nn-H chủ_tịch)) (NP (Nun-H huyện))) (Cp cùng) (NP (ADJP (Aa-H nhiều)) (Nn-H cán_bộ) (Nn địa_phương))) (VP (Vv-H bị) (VP-CMP (Vv-H kỷ_luật) (NP-DOB (NONE *T*-1)) (VP (Vv-H cách_chức)))))))))))) (PU .))
#
# Dev_25432 (S (S (NP-SBJ (NONE *-1)) (VP-MNR (Vv-H Trả_lời) (VP-CMP (Vv-H phỏng_vấn)))) (PU ,) (NP-SBJ-1 (Nn-H ông) (Nr Lộc)) (VP (Vv-H nói) (SBAR-CMP (Cs *0*) (PU :) (S (S (VP-SBJ (Vv-H Bán) (NP (Nn-H đất)) (PP (Cs-H với) (NP (Nn-H-1 giá) (VP (R không) (Vv-H được) (S-CMP (NP-SBJ (Nn-H uỷ_ban) (NP (Nun-H tỉnh))) (VP (Vv-H phê_duyệt) (NP-DOB (Nn-H *D*-1)))))))) (VP (M là) (R không_thể) (Vv-H chấp_nhận) (R được))) (PU ,) (S (NP-SBJ (Pd-H đây)) (VP (Vc-H là) (NP-CMP (Nn-H việc_làm) (VP (Vv-H vượt) (NP (Nn-H cấp))) (PP (Cs-H của) (NP (Nn-H uỷ_ban) (NP (Nun-H huyện))))))) (PU ,) (S (NP-SBJ (Nn-H loại) (Nn dự_án) (Pd này)) (VP (VP (ADJP (R không) (Aa-H phải)) (Vv-H muốn) (VP (Vv-H bán) (NP-CMP (Nn-H giá) (Pd nào)))) (Cp thì) (VP (Vv-H bán)))) (PU ,) (S (NP-SBJ (Pd-H đây)) (VP (Vc-H là) (NP-CMP (Nn_swsp (Ncs-H cái) (Aa sai)))))))) (PU .))
#
# Dev_25432 (S (Cp Nói_tóm_lại) (M là) (S-CND (NP-SBJ (Nn-H giá)) (VP (R chưa) (Vv-H duyệt))) (Cp thì) (S (NP-SBJ (NONE *E*)) (VP (R không) (Vv-H được) (VP-CMP (Vv-H bán)))) (PU .))
#
# Dev_25432 (S (NP-VOC (E Thưa) (Pp-H ông)) (PU ,) (NP-SBJ-1 (Nn-H sổ_đỏ)) (VP (R đã) (Vv-H được) (VP-CMP (Vv-H giao) (NP-DOB (NONE *T*-1)) (PP-IOB (Cs-H cho) (NP (Nn_swsp (Nc-H người) (Nn dân)))))) (PU .))
#
# Dev_25432 (S (NP-SBJ (Pp-H Tôi)) (VP (R rất) (Vv-H lấy) (VP (Vv-H làm) (ADJP (Aa-H lạ) (SBAR (Cs là) (S (S (Cp vì) (NP-PRP (Pp-H sao)) (NP-SBJ (Pp-H tôi)) (VP (R không) (Vv-H cho_phép))) (Cp mà) (S (PP-ADV (Cs-H ở) (NP (Nn-H dưới))) (NP-SBJ (NONE *E*)) (VP (R vẫn) (Vv-H làm)))))))) (PU .))
#
# Dev_25432 (S (NP-TMP (Nt-H Hiện)) (NP-SBJ (Pp-H chúng_tôi)) (VP (R vẫn) (Vv-H tiếp_tục) (VP-CMP (Vv-H điều_tra) (VP-PRP (Vv-H làm) (ADJP (Aa-H rõ) (NP (Nn-H động_cơ) (PP (Cs-H của) (NP (Nn-H cán_bộ) (Nn địa_phương)))))))) (PU .))
#
# Dev_25432 (S (NP-SBJ (Pp-H Chúng_tôi)) (VP (Vv-H xem) (NP-DOB (Pd-H đây)) (PP-CMP (Cs-H như) (NP (Num một) (Ncs-H vụ) (VP (Vv-H đấu_tranh) (VP (Vv-H chống) (NP (Nn-H tiêu_cực) (PP (Cs-H trong) (NP (Nn-H bộ_máy) (Nn nhà_nước) (PP (Cs-H của) (NP (Pp-H chúng_tôi))))))))))) (PU .))
#
# Dev_25432 (SQ (S (NP-SBJ (Nn_swsp (Nc-H Người) (Nn dân))) (VP (Vv-H tuân_thủ) (ADJP-MNR (Aa-H đúng) (NP (Nn-H pháp_luật))))) (PU ,) (S (NP-SBJ (Nn-H chính_quyền)) (VP (Vv-H sai_phạm) (PP (Cs-H về) (NP (Nn-H thủ_tục) (Vv quản_lý))))) (PU ,) (SQ (QNP-PRP (Pp-H sao)) (NP-SBJ (Nn_swsp (Nc-H người) (Nn dân))) (VP (Vv-H phải) (VP-CMP (Vv-H gánh_chịu) (NP-DOB (Nn-H hậu_quả))))) (PU ?))
#
# Dev_25432 (SQ (S (NP-SBJ (Nn-H Chính_quyền)) (UCP-PRD (ADJP (Aa-H sai)) (Cp thì) (VP (Vv-H sửa)))) (PU ,) (S (Cp chứ) (QNP-PRP (Pp-H sao)) (NP-SBJ (NONE *E*)) (VP (VP (RP (R lại) (R-H chỉ)) (Vv-H sửa) (NP-DOB (Nn-H chính_quyền))) (Cp mà) (VP (R không) (Vv-H sửa) (NP-DOB (Nn-H bên) (Nn dân))))) (PU ?))
#
# Dev_25432 (S (NP-SBJ (Pp-H Tôi)) (VP (R đã) (Vv-H chấp_nhận) (VP (Vv-H cho) (VP-CMP (Vv-H trả) (R lại) (NP (NP (Nn-H tiền)) (Cp và) (NP (Nn-H lãi) (Nn ngân_hàng))) (PP-TMP (Cs-H từ) (NP (Nq mấy) (Nu-H năm) (Nt nay)))))) (PU .))
#
# Dev_25432 (S (S-PRP (Cp Bởi) (NP-SBJ (Nn-H giá) (NP-TMP (Nt-H hồi) (Pd đó))) (VP (ADJP (R không) (Aa-H phải)) (Vc-H là) (NP-CMP (Nn-H giá)) (SBAR-PRP (Cs vì) (S (NP-SBJ (R không) (Pp-H ai)) (VP (Vv-H cho_phép)))))) (PU ,) (S (NP-SBJ (NONE *E*)) (ADJP (Aa-H chắc_chắn) (SBAR (Cs là) (SPL (VP (Ve-H có) (NP-CMP (Nn-H cái) (Pp gì) (NP (Nn-H bên) (Nn trong))) (R nữa)))))) (PU ...))
#
# Dev_25432 (SQ (VP (R Cũng) (Ve-H có) (NP-CMP (Nn-H ý_kiến) (VP (Vv-H cho) (SBAR-CMP (Cs rằng) (S (S (NP-TMP (Nt-H lúc) (SBAR (Cs *0*) (S (NP-SBJ (NONE *E*)) (VP (Vv-H bán) (NP-DOB (Nn-H đất)))))) (NP-SBJ (Nn-H giá) (NP-TMP (Nt-H khi) (Pd đó))) (ADJP-PRD (R còn) (Aa-H rẻ))) (PU ,) (S (S-TMP (NP-TMP (Pd-H bây_giờ)) (NP-NP (Nn-H giá) (Nn đất) (NP (Nn-H thị_trường))) (VP (Vv-H lên) (ADJP-CMP (Aa-H cao)))) (Cp thì) (NP-SBJ (Nun-H tỉnh) (Nr Phú_Yên)) (VP (R lại) (Vv-H thu_hồi)))))))) (PU ?))
#
# Dev_25432 (S (S (PP-TMP (Cs-H Trong) (NP (Nt-H thời_điểm) (PP (Cs-H vào) (NP (Nt-H năm) (Num 2000))))) (PU ,) (NP-SBJ (Nn-H bản_thân) (NP-1 (Nn-H chính_quyền) (NP (Nun-H huyện)))) (VP (R không) (Ve-H có) (NP-CMP (Nn-H quyền) (PP-PRP (Cs-H để) (VP (Vv-H cấp) (NP (Nn-H đất) (Vv ở))))))) (PU ,) (S (S-PRP (NP-SBJ (NONE *-1)) (VP (RP (R đã) (R-H không)) (Ve-H có) (NP-CMP (Nn-H thẩm_quyền)))) (Cp thì) (S (NP-SBJ (Nn_swsp (Ncs-H việc) (Vv mua_bán)) (Pd này)) (VP (R không) (Ve-H có) (NP-CMP (Nn-H hiệu_lực) (Nn pháp_luật))))) (PU .))
#
# Dev_25432 (S (Cp Hơn_nữa) (NP-SBJ-1 (Nn-H giá_cả)) (VP (Vv-H phải) (VP-CMP (Vv-H được) (S-CMP (NP-SBJ (Nn-H uỷ_ban) (NP (Nun-H tỉnh))) (VP (Vv-H cho_phép) (NP-DOB (NONE *T*-1)))))) (PU .))
#
# Dev_25432 (S (NP-SBJ (NONE *E*)) (VP (ADJP (Aa-H Có_thể)) (Vv-H coi) (SBAR-CMP (Cs *0*) (S (NP-SBJ (Pd-H đây)) (VP (Vc-H là) (NP-CMP (Nn-H hợp_đồng) (ADJP (Aa_w (Sv vô) (Aa-H hiệu)))))))) (PU .))
#
# Dev_25480 (SQ-HLN (NP-PRN-1 (Nn-H Đường) (NP (Nn_w (Sv liên) (Nn-H cảng))) (Nr A5)) (PU :) (VP (Vv-H Liệu) (SBAR-CMP (Cs *0*) (SQ (NP-SBJ (NONE *-1)) (VP (R có) (PU ") (Vv-H chìm_xuồng) (PU "))))) (PU ?))
#
# Dev_25480 (S (VP-MNR (Vv-H Liên_quan) (PP (Cs-H đến) (NP (Nn_swsp (Ncs-H vụ) (Aa tiêu_cực)) (PP (Cs-H ở) (NP (Nn-H công_trình) (NP (Nn-H đường) (NP (Nn_w (Sv liên) (Nn-H cảng))) (Nr A5)) (LBRK LBRK) (NP-PRN-LOC (Nun-H quận) (Nr 7)) (RBRK RBRK)))))) (PU ,) (NP-TMP (Nt-H sáng) (NP (Nt-H 23_-_3_–_2004))) (PU ,) (PP-ADV (Cs-H tại) (NP (Nn_swsp (Ncs-H cuộc) (Vv họp)) (PP (Cs-H với) (NP (Nn-H lãnh_đạo) (NP (Nq các) (Nn-H sở) (PU ,) (Nn-H ngành) (NP (Nun-H TP))))))) (PU ,) (NP-SBJ (Nn-H Chủ_tịch) (NP (X-H UBND) (NP (Nun-H TP) (Nr HCM))) (Nr Lê_Thanh_Hải)) (VP (R đã) (Vv-H đề_nghị) (SBAR-CMP (Cs *0*) (S (NP-SBJ (Nn-H Công_an) (NP (Nun-H TP) (Nr HCM))) (VP (Vv-H báo_cáo) (NP-DOB (Nn-H tiến_độ) (Vv điều_tra)) (PP-IOB (Cs-H với) (NP (X-H UBND) (NP (Nun-H TP)))))))) (PU .))
#
# Dev_25480 (S (NP-SBJ (Nn-H Ông) (Nr Hải)) (VP (Vv-H đặt) (NP-DOB (Nn-H vấn_đề) (SBAR (Cs *0*) (PU :) (VP (Vv-H liệu) (SBAR-CMP (Cs *0*) (SQ (S (NP-SBJ (Nn-H vụ_việc)) (VP (VP (R có) (PU ") (Vv-H-1 chìm_xuồng) (PU ")) (Cp hay) (VP (R không) (Vv *H*-1)))) (PU ,) (SQ (Cp vì) (NP-PRP (Pp-H sao)) (PP-TMP (Cs-H đến) (NP (Nt-H nay))) (NP-SBJ (NONE *E*)) (VP (RP (R vẫn) (R-H chưa)) (Ve-H có) (NP-CMP (Nn-H kết_quả)))))))))) (PU ?))
#
# Dev_25480 (S (NP-SBJ (Nn-H Ông) (Nr Hải)) (VP (R cũng) (Vv-H chỉ_đạo) (SBAR-CMP (Cs *0*) (S (NP-SBJ (Nn-H Sở) (X GTCC)) (VP (Vv-H báo_cáo) (PP (Cs-H về) (VP (Vv-H xử_lý) (NP-DOB (Nn-H tiêu_cực) (PP (Cs-H ở) (NP (Nn-H công_trình) (Pd này)))))))))) (PU .))
#
# Dev_25480 (S (NP-TMP (Nt-H Chiều) (NP (Nt-H 23-3))) (PU ,) (S (NP-SBJ (NONE *-1)) (VP-MNR (Vv-H trả_lời) (NP (Nn-H Tuổi_Trẻ)) (PP-TMP (Cs-H sau) (NP (Nn_swsp (Nc-H-2 phiên) (Vv họp)) (VP (Vv *P*) (VP (Vv-H nói) (NP-DOB (Nn *D*-2)) (NP (Nn-H trên)))))))) (PU ,) (NP-SBJ-1 (Nn-H lãnh_đạo) (NP (Nn-H Cơ_quan) (NP (Nn-H cảnh_sát) (Vv điều_tra) (NP (Nn-H Công_an) (NP (Nun-H TP) (Nr HCM)))) (PU -) (NP-PRN (Nn-H nơi) (VP (R đang) (Vv-H thụ_lý) (NP-DOB (Nn_swsp (Ncs-H vụ) (Aa tiêu_cực)) (PP (Cs-H tại) (NP (Nn-H công_trình) (NP (Nn-H đường) (NP (Nn_w (Sv liên) (Nn-H cảng))) (Nr A5))))))) (PU -))) (VP (Vv-H cho) (NP-IOB (NONE *E*)) (VP-CMP (Vv-H biết) (SBAR-CMP (Cs *0*) (S (S (NP-SBJ (Nn_swsp (Nc-H vụ) (Nn án))) (PP-PRD (RP (R vẫn) (R-H đang)) (Cs-H trong) (NP (Nn-H giai_đoạn) (Vv điều_tra)))) (PU ,) (S (NP-SBJ (NONE *E*)) (VP (R chưa) (Ve-H có) (NP-CMP (Nn-H kết_luận) (ADJP (Aa-H cuối_cùng))))))))) (PU .))
#
# Dev_25480 (S (NP-SBJ (NONE *E*)) (VP (Vv-H Trả_lời) (NP (Nn-H câu) (Vv hỏi) (SBAR (Cs *0*) (PU :) (SQ (S-CNC (Cp vì) (QNP-PRP (Pp-H sao)) (NP-SBJ (Nn_swsp (Ncs-H vụ) (Aa tiêu_cực))) (VP (Vv-H gây) (NP-CMP (ADJP (Aa-H nhiều)) (Nn-H bức_xúc) (PP (Cs-H trong) (NP (Nn-H dư_luận)))))) (Cp mà) (S (S (NP-SBJ (NONE *E*)) (VP (Vv-H phải) (VP-CMP (Vv-H để) (ADJP-TMP (R quá) (Aa-H lâu))))) (PU ,) (S (PP-TMP (Cs-H đến) (NP (Nt-H nay) (NP (R đã) (QP (R hơn) (Num-H hai)) (Nu-H năm)))) (NP-SBJ (NONE *E*)) (VP (RP (R vẫn) (R-H chưa)) (Ve-H có) (NP-CMP (Nn-H kết_luận) (Pp gì))))))))) (PU .))
#
# Dev_25480 (S (NP-SBJ (Nn-H Lãnh_đạo) (NP (Nn-H cơ_quan) (Vv điều_tra))) (VP (Vv-H giải_thích) (SBAR-CMP (Cs *0*) (PU :) (S (PP-ADV (Cs-H ngoài) (NP (Nn-H nguyên_nhân) (PP-PRP (Cs-H do) (ADJP (Aa-H thiếu) (NP (Nn_w (Vv-H điều_tra) (Sv viên))))))) (PU ,) (Cp còn) (NP-SBJ (Nn-H nguyên_nhân) (Aa khác) (VP (Vv-H khiến) (Cs *0*) (SBAR-CMP (S (NP-SBJ (Nn-H công_tác) (Vv điều_tra)) (VP (Vv-H phải) (VP-CMP (Vv-H kéo) (ADJP (Aa-H dài)))))))) (VP (Vc-H là) (PP-CMP-PRP (Cs-H do) (S (NP-SBJ (NONE *E*)) (VP (Vv-H vướng) (PP (Cs-H ở) (NP (Nn-H khâu) (Vv giám_định)))))))))) (PU .))
#
# Dev_25480 (S (VP-MNR (Vv-H Theo) (NP (Pd-H đó))) (PU ,) (S (NP-SBJ (NONE *-1)) (VP-MNR (Vv-H muốn) (VP (Vv-H khởi_tố) (PU ,) (Vv-H truy_tố) (R được) (NP-DOB (Nq những) (Nn-H cá_nhân) (Vv sai_phạm))))) (PU ,) (NP-SBJ-1 (Nn-H cơ_quan) (Vv điều_tra)) (VP (Vv-H buộc) (VP-CMP (Vv-H phải) (VP-CMP (Vv-H chứng_minh) (PP-MNR (Cs-H bằng) (NP (Nn-H chứng_cứ))) (PU ,) (Cp tức) (VP-PRN (Vv-H phải) (VP-CMP (Ve-H có) (NP-CMP (Nq các) (Nn-H số_liệu) (ADJP (Aa-H thực_tế)) (PP (Cs-H về) (NP (Nn-H-1 vật_liệu) (VP (Vv-H bị) (VP-CMP (Vv-H bớt_xén) (NP-DOB (Nn *D*-1)))))))))))) (PU ...))
#
# Dev_25480 (S (PP-PRP (Cs-H Để) (VP (Ve-H có) (NP-CMP (Nq các) (Nn-H số_liệu) (Nn trên)))) (PU ,) (NP-SBJ (Nn-H Công_an) (NP (Nun-H TP))) (PP-TMP (Cs-H trước) (NP (Pd-H đó))) (VP (R đã) (Ve-H có) (NP-CMP (Nn-H văn_bản) (VP (Vv-H đề_nghị) (SBAR-CMP (Cs *0*) (S (NP-SBJ (X-H UBND) (NP (Nun-H TP) (Nr HCM))) (VP (Vv-H thành_lập) (NP-DOB (Nn-H hội_đồng) (VP (Vv-H giám_định) (VP (Vv-H xây_dựng) (NP (Nn-H công_trình) (Pd này))))))))))) (PU .))
#
# Dev_25480 (S (NP-TMP (Nt-H Mới_đây)) (PU ,) (NP-SBJ (Nn-H cơ_quan) (Vv điều_tra)) (VP (R có) (Vv-H nhận) (M được) (NP-DOB (Nn-H kết_quả) (VP (Vv-H giám_định) (VP (Vv-H xây_dựng) (NP (Nn-H công_trình) (NP (Nn-H đường) (NP (Nn_w (Sv liên) (Nn-H cảng))) (Nr A5)))))) (PP-IOB (Cs-H từ) (NP (Nn-H hội_đồng) (Pd này)))) (PU .))
#
# Dev_25480 (S (Cp Tuy_nhiên) (PP-TMP (Cs-H sau) (NP (Nt-H khi) (SBAR (Cs *0*) (S (NP (NP-SBJ (NONE *E*)) (Cp cùng) (NP (Nn-H Viện_Kiểm_sát) (Nn nhân_dân) (NP (Nun-H TP)))) (VP (Vv-H đánh_giá)))))) (NP-SBJ (NONE *E*)) (VP (Vv-H thấy) (SBAR-CMP (Cs rằng) (S (NP-SBJ-1 (Nn-H kết_luận) (Nn trên)) (UCP-PRD (ADJP (R còn) (Aa-H chung_chung)) (PU ,) (ADJP (R chưa) (Aa-H cụ_thể)) (Cp và) (VP (R chưa) (Vv-H thể) (VP-CMP (Vv *P*) (VP-CMP (Vv-H dùng) (NP-DOB (NONE *T*-1)) (VP-PRP (Vv-H làm) (NP-CMP (Nn-H chứng_cứ) (Vv điều_tra)))))))))) (PU .))
#
# Dev_25480 (S (Cp Do) (SPL-PRP (NP (Pp-H vậy))) (S (S (NP-SBJ-1 (Nn-H cơ_quan) (Vv điều_tra)) (VP (R đã) (Vv-H phải) (VP-CMP (Vv-H yêu_cầu) (VP-CMP (Vv_w (Sv tái) (Vv-H giám_định)))))) (PU ,) (Cp nhưng) (S (NP-SBJ (NONE *-1)) (VP (R chưa) (Ve-H có) (NP-CMP (Nn-H kết_quả))))) (PU .))
#
# Dev_25480 (S (S (PP-TMP (Cs-H Trước) (NP (Pd-H đó))) (PU ,) (NP-SBJ (Nn-H Thanh_tra) (NP (Nun-H TP) (Nr HCM))) (VP (RP (R cũng) (R-H có)) (Vv-H chuyển) (PP-IOB (Cs-H cho) (NP-1 (Nn-H cơ_quan) (Vv điều_tra))) (NP-DOB (Nn-H kết_quả) (VP (Vv-H thanh_tra) (NP (Nn-H công_trình)))))) (PU ,) (Cp nhưng) (S (Cp do) (S-PRP (NP-SBJ (Nn-H đặc_điểm) (PP (Cs-H của) (NP (Nn-H thanh_tra))) (PP (Cs-H trong) (NP (Nn-H vụ) (Pd này)))) (VP (Vc-H là) (VP-CMP (Vv-H lấy) (NP-DOB (Nn-H mẫu)) (PU ,) (Cp tức) (VP-PRN (Vv-H thanh_tra) (ADJP (R không) (Aa-H toàn_diện)) (NP-DOB (Nw cả) (Nn-H công_trình)))))) (PU ,) (Cp nên) (S (NP-SBJ (NONE *-1)) (VP (RP (R cũng) (R-H không_thể)) (Vv-H lấy) (NP-DOB (Pd-H đó)) (VP-PRP (Vv-H làm) (NP-CMP (Nn-H chứng_cứ)))))) (PU .))
#
# Dev_25480 (S (VP-MNR (Vv-H Theo) (NP (Nn-H cơ_quan) (Vv điều_tra))) (PU ,) (NP-SBJ (Nn-H vụ_việc)) (VP (VP (RP (R sẽ) (R-H không)) (Vv-H bị) (VP-CMP (PU ") (Vv-H chìm_xuồng) (PU ") (PP (Cs-H như) (S (NP-SBJ (Nn-H dư_luận)) (VP (Vv-H nghi_vấn)))))) (PU ,) (Cp nhưng) (VP (ADJP (Aa-H chắc_chắn)) (RP (R sẽ) (R-H không)) (VA-H tận_cùng) (PP (Cs-H như) (NP (Nn-H mong_muốn))))) (PU .))
#
# Dev_25480 (SQ (Cp Vì) (QNP-PRP (Pp-H sao)) (PU ?))
#
# Dev_25480 (S (NP-SBJ (Nn-H Lãnh_đạo) (NP-1 (Nn-H Cơ_quan) (NP (Nn-H cảnh_sát) (Vv điều_tra)))) (VP (Vv-H trả_lời) (SBAR-CMP (Cs *0*) (PU :) (S (Cp vì) (NP-SBJ (NONE *-1)) (VP (RP (R sẽ) (R-H không)) (Ve-H có) (NP-CMP (Nn-H khả_năng) (VP (Vv-H bới) (VP (Ve-H hết)) (NP-DOB (Nn-H công_trình)) (R lên) (PP-PRP (Cs-H để) (VP (Vv-H kiểm_tra) (NP (NP (Pp từng) (Nn-H cây) (Nn cừ)) (PU ,) (NP (Pp từng) (Nu-H mét) (Nn sắt))))))) (R được))))) (PU .))
#
# Dev_25480 (SPL (NP (Nn-H Tin) (Nn-H bài) (VP (Vv-H liên_quan)) (PU :) (S-PRN (NP-SBJ (NONE *E*)) (VP (Vv-H Viết) (VP (Vv-H tiếp)) (PP (Cs-H về) (NP (Nn-H vụ) (NP (Nn-H anh) (Nr Trương_Xuân_Đại))))))) (PU .))
#
# Dev_25480 (S (NP-SBJ (Nn-H Công_nhân) (Nr Trương_Xuân_Đại)) (VP (Vv-H kiện) (NP-DOB (Nn-H báo) (Nn Pháp_Luật) (NP (Nun-H TP) (Nr HCM)))) (PU .))
#
# Dev_25480 (S (NP-SBJ (Nn-H Luật_sư) (VP (Vv-H bảo_vệ) (NP (Nn-H quyền_lợi) (NP (Nn-H báo) (Nn Pháp_Luật))))) (VP (Vv-H đề_nghị) (VP-CMP (Vv-H hoà_giải))) (PU .))
#
# Dev_25480 (S (NP-SBJ (Nn-H Công_dân) (Nr Trương_Xuân_ĐạI)) (VP (Vv-H thắng) (NP-CMP (Nn-H kiện))) (PU .))
#
# Dev_25480 (SPL (NP (Nn-H Số_phận) (PP (Cs-H của) (NP (Nq những) (Nn-H người) (VP (Vv-H nói) (R lên) (NP (Nn-H sự_thật)))))) (PU .))
#
# Dev_25480 (S (NP-SBJ (NONE *E*)) (VP (Vv-H Đấu_thầu) (R lại) (NP-DOB (Nn-H đường) (NP (Nn_w (Sv liên) (Nn-H cảng))) (Nr A5))) (PU .))
#
# Dev_25480 (SQ (NP-SBJ-1 (Nn-H Đường) (NP (Nn_w (Sv liên) (Nn-H cảng))) (Nr A5)) (VP (Vv *P*) (VP-CMP (Vv-H thi_công) (R lại) (NP-DOB (NONE *T*-1)) (PP-TMP (Cs-H vào) (PP (Cs-H cuối) (NP (Nt-H tháng) (Nt 3_-_2004)))))) (PU ?))
#
# Dev_25480 (SQ (NP-SBJ (Nn_swsp (Ncs-H Vụ) (Vv sai_phạm)) (NP (Nn-H công_trình) (NP (Nn-H đường) (NP (Nn_w (Sv liên) (Nn-H cảng))) (Nr A5)))) (VP (R có) (Vv-H bị) (PU ") (VP-CMP (Vv-H chìm_xuồng)) (PU ")) (PU ?))
#
# Dev_25600 (S-HLN (S-PRN (NP-TMP (Nt-H Ngày) (NP (Nn-H thứ) (An ba))) (NP-SBJ (NONE *E*)) (VP (Vv-H phúc_thẩm) (NP-DOB (Nn_swsp (Nc-H vụ) (Nn án)) (NP (Nr-H Lã_Thị_Kim_Oanh))))) (PU :) (NP-SBJ (Nn_w (Nn-H Bộ) (Sv trưởng))) (VP (Vv-H ra) (NP-CMP (Nn-H toà)) (VP-PRP (Vv-H làm) (NP-CMP (Nn-H nhân_chứng)))) (PU .))
#
# Dev_25600 (S (NP-TMP (Nt-H Chiều) (NP (Nt-H 24_-_3))) (PU ,) (NP-SBJ (Nn_w (Nn-H bộ) (Sv trưởng)) (NP (Nn-H Bộ) (UCP (NP (Nn-H Nông_nghiệp)) (Cp và) (VP (Vv-H phát_triển) (NP (Nn-H nông_thôn))) (LBRK LBRK) (NP-PRN (X-H NN_&_PTNT)) (RBRK RBRK))) (Nr Lê_Huy_Ngọ)) (VP (R đã) (Vv-H xuất_hiện) (PP (Cs-H tại) (NP (Nn-H trụ_sở) (NP (Nn-H Toà_án) (Nn Nhân_dân) (Aa Tối_cao)))) (PP-PRP (Cs-H để) (VP (Vv-H làm_chứng) (PP (Cs-H trong) (NP (Nn_swsp (Ncs-H phiên) (Vv phúc_thẩm)) (VP (Vv-H xét_xử) (NP (NP (Nn-H bị_cáo) (Nr Lã_Thị_Kim_Oanh)) (Cp và) (NP (Nn_w (Sv đồng) (Nn-H phạm)))))))))) (PU .))
#
# Dev_25600 (S (VP-TPC-1 (Vv-H Tháp_tùng) (NP (Nn_w (Nn-H bộ) (Sv trưởng)) (Nr Ngọ))) (Cp là) (NP-SBJ (Nq một_số) (Nn-H cán_bộ) (NP (Nn-H cấp) (Nn vụ)) (PP (Cs-H của) (NP (Nn-H Bộ) (X NN_&_PTNT))) (PU ,) (VP-PRN (R cũng) (Vc-H là) (NP-CMP (Nn-H nhân_chứng) (PP (Cs-H của) (NP (Nn_swsp (Nc-H vụ) (Nn án))))))) (VP (NONE *T*-1)) (PU .))
#
# Dev_25600 (S (NP-SBJ (Nn_swsp (Nc-H Vị) (Nn nhân_chứng)) (ADJP (Aa-H đặc_biệt)) (Pd này)) (VP (VP (ADJP (Aa-H vội_vã)) (Vv-H lên) (NP-CMP (Nn-H cầu_thang)) (PP-PRP (NONE *-1))) (Cp và) (VP (Vv-H đi) (VP (D-H vào) (NP-CMP (Nn-H bên) (Nn trong) (NP (Nn-H phòng) (Vv xử)))) (ADJP (R rất) (Aa-H nhanh)) (PP-PRP-1 (Cs để) (VP (Vv-H tránh) (NP (Nn-H ống_kính) (Nn máy_ảnh) (PP (Cs-H của) (NP (Nq các) (Nn-H phóng_viên)))))))) (PU .))
#
# Dev_25600 (S (S (NP-SBJ (NONE *-1)) (VP-PRP (Vv-H Muốn) (VP-CMP (Vv-H biết) (ADJP-CMP (Aa-H đúng) (Cp hay) (Aa-H sai))))) (NP-SBJ-1 (Nn-H toà)) (VP (Vv-H phải) (VP-CMP (Vv-H nhờ) (PU ...) (NP-DOB (Nn-H hội_đồng) (Vv thẩm_định)))) (PU .))
#
# Dev_25600 (S (NP-SBJ (Nn-H Hội_đồng) (Vv xét_xử) (LBRK LBRK) (NP-PRN (X-H HĐXX)) (RBRK RBRK)) (VP (Vv-H hỏi) (NP-DOB-1 (Nn-H bị_cáo) (Nr Nguyễn_Quang_Hà) (NP-PRN (Nn_w (Sv nguyên) (Nn-H thứ_trưởng)) (NP (Nn-H Bộ) (X NN_&_PTNT)))) (SBAR-CMP (Cs *0*) (PU :) (PU ") (SQ (NP-SBJ (NONE *-1)) (VP (Vv-H Muốn) (VP-CMP (Vv-H đối_chất) (PP (Cs-H với) (NP (Nn_w (Nn-H bộ) (Sv trưởng)) (Nr Lê_Huy_Ngọ))) (PP-CMP (Cs-H về) (NP (Nq những) (Nn-H vấn_đề) (Pp gì))))) (PU ?)) (PU "))) (PU .))
#
# Dev_25600 (S (PU ") (S-1 (NP-SBJ (Pp-H Tôi)) (VP (Vv-H muốn) (SBAR-CMP (Cs *0*) (S (NP-SBJ (Nn-H anh) (Nr Ngọ)) (VP (Vv-H đánh_giá) (PP (Cs-H về) (NP (Nn-H công_việc) (Cp và) (Nn-H trách_nhiệm) (PP (Cs-H của) (NP (Pp-H tôi))) (PP (PP (Cs-H ở) (NP (Nn-H Bộ) (X NN_&_PTNT))) (PU ,) (CONJP (R cũng) (Cp-H như)) (PP (Cs-H trong) (NP (Nn-H sự_việc) (Pd này))))))))))) (PU ") (PU ,) (NP-SBJ (Nn-H bị_cáo) (Nr Hà)) (VP (Vv-H trình_bày) (SBAR-CMP (Cs *0*) (S (NONE *T*-1)))) (PU .))
#
# Dev_25600 (S (S (NP-SBJ (Nn-H Nhân_chứng) (Nr Lê_Huy_Ngọ)) (VP (Vv-H xác_nhận) (SBAR-CMP (Cs *0*) (PU :) (PU ") (S (NP-SBJ (Nn-H Anh) (Nr Hà)) (VP (Vc-H là) (NP-CMP (Nn-H người) (VP (Vv-H làm_việc) (VP (Ve-H có) (NP-CMP (Nn-H trách_nhiệm)))))))) (PU "))) (PU ,) (Cp nhưng) (S (ADJP-ADV (Aa-H cụ_thể) (PP (Cs-H trong) (NP (Nn-H sự_việc) (Pd này) (LBRK LBRK) (NP-PRN (Nn-H vụ) (NP (Nr-H Lã_Thị_Kim_Oanh))) (RBRK RBRK)))) (Cp thì) (PU ") (NP-TMP (Nn-H thời_gian) (NP (QP (Num-H 5) (PU -) (Num-H 6)) (Nu-H năm) (R rồi))) (PU ,) (PP-ADV (Cs với) (NP (Nn-H khối_lượng) (NP (Nn-H công_việc) (PP (Cs-H của) (NP (Nn_w (Nn-H bộ) (Sv trưởng))))))) (PU ,) (NP-SBJ (Pp-H tôi)) (VP (R không_thể) (M nào) (Vv-H nhớ) (VP (Ve-H hết)) (R được)) (PU ")) (PU .))
#
# Dev_25600 (S (PU ") (SQ-1 (NP-SBJ (Pp-H Ông)) (VP (Vv-H nhận_thức) (PP (Cs-H như) (NP (Pp-H thế_nào))) (PP (Cs-H về) (NP (Nn-H công_văn) (Nr 327) (PP (Cs-H của) (NP (Nn-H Chính_phủ))))))) (PU ") (PU ,) (NP-SBJ (Nn-H đại_diện) (NP (Nn-H Viện) (Vv Kiểm_sát))) (VP (Vv-H đặt) (NP-DOB (Nn-H câu) (Vv hỏi) (SBAR (Cs *0*) (SQ (NONE *T*-1)))) (PP-IOB (Cs-H cho) (NP (Nn-H nhân_chứng) (PU -) (NP-PRN (Nn_w (Nn-H bộ) (Sv trưởng)) (Nr Lê_Huy_Ngọ))))) (PU .))
#
# Dev_25600 (S (NP-SBJ (Nn-H Ông) (Nr Ngọ)) (VP (Vv-H giải_trình) (SBAR-CMP (Cs *0*) (PU :) (S (NP-SBJ (Pd-H Đây)) (VP (Vc-H là) (NP-CMP (Nn_swsp (Ncs-H sự) (Vv trả_lời)) (PP (Cs-H của) (NP (Nn-H Chính_phủ))) (PU ,) (S-PRN (PP (Cs-H trong) (NP (Pd-H đó))) (NP-SBJ (Nn-H chủ_trương)) (VP (Vv-H đồng_ý) (VP-CMP (Vv-H cho) (NP-IOB (NONE *E*)) (VP-CMP (Vv-H tăng) (NP-DOB (Nn-H vốn)) (PP-TMP (Cs-H trong) (NP (Num 6) (Nu-H tháng) (PP (Cs-H đầu) (NP (Nt-H năm) (Num 1998))))) (PP-PRP (Cs-H để) (S (NP-SBJ (Nn-H Công_ty) (Vv Tiếp_thị)) (VP (ADJP (Aa-H có_thể)) (Vv-H hoàn_thành) (NP-DOB (Nn-H nhiệm_vụ)))))))))))))) (PU .))
#
# Dev_25600 (S (NP-SBJ (Pd-H Đó)) (VP (Cp vừa) (VP (Vc-H là) (NP-CMP (Num một) (Nn-H quyết_định) (PU ") (ADJP (Aa-H đúng) (NP (Nn-H thẩm_quyền))) (PU "))) (PU ,) (Cp vừa) (VP (Vc-H là) (NP-CMP (Nn-H chủ_trương) (PU ") (VP (Vv-H tháo_gỡ) (NP (Nn-H khó_khăn) (PP (Cs-H của) (NP (Nn-H công_trình) (NP (Nn-H nhóm) (Nr A)))))) (PU ")))) (PU .))
#
# Dev_25600 (S (NP-SBJ (Nn-H Công_văn) (Nr 327)) (VP (R có) (Vv-H ghi) (VP-CMP (Vv-H đồng_ý) (PP (Cs-H như) (NP (Nn-H đề_nghị) (PP (Cs-H của) (NP (Nn-H Bộ) (X KHĐT))))) (VP (Vv-H cho_phép) (NP-IOB (Nn-H Công_ty) (Vv Tiếp_thị)) (VP-CMP (Vv-H vay) (NP-DOB (Nn-H vốn) (Nn tín_dụng)) (VP-MNR (Vv-H theo) (NP (Nn-H kế_hoạch) (NP (Nn-H Nhà_nước)) (NP-TMP (Nt-H năm) (Num 1998)))))))) (PU .))
#
# Dev_25600 (S (PU ") (SQ-1 (NP-SBJ (Pp-H Ông)) (VP (Vv-H hiểu) (SBAR-CMP (Cs *0*) (S (NP-SBJ (Nn-H vốn) (Nn tín_dụng) (PP (Cs-H ở) (NP (Pd-H đây)))) (VP (Vc-H là) (QNP-CMP (Nn-H vốn) (PU ...) (QNP (Pp-H gì))))))) (PU ?)) (PU ") (PU ,) (NP-SBJ (Nn-H đại_diện) (NP (Nn-H Viện) (Vv Kiểm_sát))) (VP (Vv-H hỏi) (VP (Vv-H tiếp)) (NP-DOB (Nn-H ông) (Nr Ngọ)) (SBAR-CMP (Cs *0*) (SQ (NONE *T*-1)))) (PU .))
#
# Dev_25600 (S (PU ") (S-1 (NP-SBJ (NONE *E*)) (VP (Vc-H Là) (NP-CMP (Nn-H tín_dụng) (VP (Vv-H ưu_đãi) (VP-MNR (Vv-H theo) (NP (Nn-H kế_hoạch) (PP (Cs-H của) (NP (Nn-H Chính_phủ)))))))) (PU ...)) (PU ") (PU ,) (NP-SBJ (Nn_swsp (Nc-H ông) (Nn_w (Nn-H bộ) (Sv trưởng)))) (VP (Vv-H trả_lời) (SBAR-CMP (Cs *0*) (S (NONE *T*-1)))) (PU .))
#
# Dev_25600 (S (NP-SBJ (R Vẫn) (Nn-H Viện) (Vv Kiểm_sát)) (VP (Vv *H*) (SBAR-CMP (Cs *0*) (PU :) (PU ") (SQ (NP-SBJ (Nn-H Bộ)) (VP (Ve-H có) (NP-CMP (Nn-H chủ_trương) (SBAR (Cs cho) (S (NP-SBJ (Nn-H thứ_trưởng)) (VP (Vv-H ký) (VP (Vv-H xác_nhận) (PP (Cs-H vào) (NP (Nn-H công_văn) (NP (Nn-H Công_ty) (Vv tiếp_thị))))))))) (R không)) (PU ?)) (PU "))) (PU .))
#
# Dev_25600 (S (PU ") (S-1 (NP-SBJ-2 (Nn-H Bộ)) (VP (R không) (Ve-H có) (NP-CMP (Nn-H chủ_trương) (Pd này)))) (PU ") (PU ,) (NP-SBJ (Nn_w (Nn-H bộ) (Sv trưởng)) (NP (Nn-H Bộ) (X NN_&_PTNT))) (VP (Vv-H khẳng_định) (SBAR-CMP (Cs *0*) (S (S (NONE *T*-1)) (PU ,) (Cp mà) (S (NP-SBJ (NONE *E*)) (VP (R chỉ) (Vc-H là) (NP-CMP (Nn-H đề_nghị) (PP (Cs-H của) (NP (Nn-H DN)))))) (Cp và) (S (NP-SBJ (NONE *-2)) (VP (Cp nếu) (VP (Vv-H xem_xét) (VP (PU ") (Vv-H thấy) (ADJP-CMP (Aa-H đúng)))) (Cp thì) (VP (Vv-H giao) (NP-IOB (Nn-H người) (VP (Vv-H phụ_trách) (NP (Nn-H lĩnh_vực)))) (VP-CMP (Vv-H ký) (PU ")))))))) (PU .))
#
# Dev_25600 (S (PP-ADV (Cs-H Như) (NP (Pp-H vậy))) (PU ,) (PU ") (S-1 (SQ (NP-SBJ (Nn_swsp (Ncs-H việc) (Vv xác_nhận)) (PP (Cs-H của) (NP (Nn-H thứ_trưởng) (Nr Hà)))) (ADJP-PRD (R có) (Aa-H cần_thiết) (R không)) (PU ?)) (LBRK LBRK) (S-PRN (NP-SBJ (Nn-H ông) (Nr Hà)) (VP (Vv-H ký) (VP (Vv-H xác_nhận) (NP-DOB (NP (Num 6) (Nn-H văn_bản) (PP-TMP (Cs-H dưới) (NP (Nt-H thời) (NP (Nn_w (Nn-H bộ) (Sv trưởng)) (Nr Ngọ))))) (PU ,) (NP (Num 1) (Nn-H văn_bản) (PP-TMP (Cs-H dưới) (NP (Nt-H thời) (NP (Nn_w (Nn-H bộ) (Sv trưởng)) (Nr Tạn))))))))) (RBRK RBRK)) (PU ") (PU ,) (NP-SBJ (Nn_w (Nn-H luật) (Sv gia)) (Nr Trần_Đình_Triển) (LBRK LBRK) (VP-PRN (Vv-H bào_chữa) (PP (Cs-H cho) (NP (Nn-H bị_cáo) (Nr Nguyễn_Quang_Hà)))) (RBRK RBRK)) (VP (PU ") (Vv-H xoay) (PU ") (NP-DOB (Nn-H nhân_chứng) (Nr Lê_Huy_Ngọ)) (SBAR-CMP (Cs *0*) (S (NONE *T*-1)))) (PU .))
#
# Dev_25600 (S (NP-SBJ (Nn-H Ông) (Nr Ngọ)) (ADJP-PRD (Aa-H lúng_túng) (SBAR (Cs *0*) (PU :) (PU ") (S (NP-SBJ (Nn-H Cái) (Pd này)) (VP (Vv-H đề_nghị) (SBAR-CMP (Cs *0*) (S (NP-SBJ (X-H HĐXX)) (VP (Vv-H cho) (VP-CMP (Vv-H thẩm_định) (PP (Cs-H ở) (NP (NP (Num một) (Nn-H hội_đồng) (Aa chuyên_môn)) (Cp hoặc) (NP (Num một) (Nn-H cơ_quan) (VP (Ve-H có) (NP-CMP (Nn-H trách_nhiệm))) (PP-PRN (Cs-H như) (NP (Nn-H ngân_hàng)))) (PU ...))))))))) (PU "))) (PU .))
#
# ...
#
# Dev_90295 (S (S (NP-SBJ (Nn-H Con) (Nn gái) (Aa đầu)) (VP (R đang) (Vv-H học) (PP (Cs-H ở) (NP (Nn-H Trường) (NP (Nn-H cao_đẳng) (Nn Sư_phạm)))))) (PU ,) (S (NP-SBJ (Nn-H con) (Nn trai) (Nr Đinh_Xuân_Cường)) (VP (VP (R vừa) (Vv-H học) (VP (VA-H xong)) (NP-DOB (Nn-H lớp) (An 8))) (Cp nhưng) (VP (R đã) (Vv-H biết) (VP-CMP (Vv-H nhảy) (NP-DOB (Nn-H xe_đò))) (VP (Vv-H ra) (ADJP-LOC (Aa-H tận) (NP (Nr-H Hải_Dương) (PU ,) (Nr-H Nam_Định) (PU ,) (Nr-H Nghệ_An))) (VP (Vv-H cắt) (NP-DOB (Nn-H thuốc_nam) (PP (Cs-H ở) (NP (Nq các) (Nn_swsp (Nc-H ông) (Nn lang))))) (VP (Vv-H về) (VP (Vv-H chữa) (NP-DOB (Nn-H bệnh)) (PP-IOB (Cs-H cho) (NP (Nn-H bố)))))))))) (PU .))
#
# Dev_90295 (S (NP-SBJ (Pp-H Tôi)) (VP (Vv-H hỏi) (SBAR-CMP (Cs *0*) (PU :) (PU ") (SQ (S (QNP-PRP (Pp-H Sao)) (NP-SBJ (Pp-H anh)) (VP (R không) (Vv-H vào) (NP-LOC (Nr-H Huế)) (VP (Vv-H chạy) (NP-CMP (Nn-H thận) (Aa nhân_tạo))))) (PU ,) (S (NP-SBJ (Pp-H anh)) (VP (Ve-H có) (NP-CMP (Nn-H bảo_hiểm) (Nn y_tế)) (M mà))) (PU ?)) (PU "))) (PU .))
#
# Dev_90295 (S (NP-SBJ (Nn-H Anh) (Nr Tăng)) (VP (VP (Vv-H lắc_đầu)) (VP (Vv-H kể) (NP-DOB (Nn-H bài_toán)) (VP (Vv-H nghe) (ADJP (Aa-H nhói) (NP (Nn-H lòng)))) (SBAR-CMP (Cs *0*) (PU :) (S (NP-SBJ (Nn-H lương) (NP (Num 900_._000) (Nu-H đồng_[]_tháng))) (VP (Vv-H chi_tiêu) (PP-IOB (Cs-H cho) (NP (Nw cả) (Nn-H gia_đình))) (PU ,) (PP (Cs-H trong) (NP (Nt-H khi) (SBAR (Cs *0*) (S (S (NP (Num một) (Nn-H lần) (VP (Vv-H chạy) (NP (Nn-H thận) (Aa nhân_tạo)))) (VP (Vv-H tốn) (NP-CMP (Num 700_._000) (Nu-H đồng)))) (PU ,) (S (NP-TMP (Nq mỗi) (Nu-H tuần)) (NP-SBJ (NONE *E*)) (VP (Vv-H chạy) (NP (QP (Num-H hai) (Cs đến) (Num-H ba)) (Nn-H lần)))))))) (PU ,) (Cp rồi) (NP-PRN (Nn-H tiền) (NP (NP (Nn-H xe_cộ)) (PU ,) (VP (Vv-H ăn_ở)) (PU ,) (NP (Nn-H thuốc_men) (VP (Vv-H bồi_dưỡng)))))))))) (PU .))
#
# Dev_90295 (S (PU ") (S-1 (Cp Thành_ra) (S (NP-SBJ (NONE *E*)) (VP (VP (RP (R vẫn) (R-H chưa)) (Vv-H dám) (VP-CMP (Vv-H đi))) (PU ,) (VP (R chỉ) (Vv-H trông_nhờ) (PP (Cs-H vào) (NP (Nn-H thuốc_nam)))))) (PU ,) (S (NP-TMP (Pp bao_giờ)) (NP-SBJ (NONE *E*)) (VP (R không_thể) (Vv-H cầm_cự) (R nổi)) (Cp thì))) (PU ...) (PU ") (PU ,) (NP-SBJ (Nn-H anh) (Nr Tăng)) (VP (Vv-H bỏ_lửng) (NP-DOB (Nn-H câu) (Vv nói)) (SBAR-CMP (Cs *0*) (S (NONE *T*-1)))) (PU .))
#
# Dev_90295 (S (NP-SBJ (Pp-H Tôi)) (VP (VP (Vv-H nhìn) (R ra) (NP-LOC (Nn-H mảnh) (Nn vườn) (ADJP (Aa-H nhỏ)) (PP (Cs-H của) (NP (Pp-H anh))))) (Cp rồi) (VP (Vv-H nhìn) (PP (Cs-H vào) (NP (Nn_swsp (Nc-H căn) (Nn nhà)) (ADJP (Aa-H tuềnh_toàng)))))) (PU .))
#
# Dev_90295 (S (NP-TPC-1 (Nw Cả) (Nn-H gia_sản) (Pd này)) (Cp nếu) (S-CND (NP-SBJ (NONE *E*)) (VP (M có) (Vv-H bán) (NP-DOB (NONE *T*-1)) (M đi) (M nữa))) (S (NP-SBJ (NONE *T*-1)) (ADJP-PRD (RP (R cũng) (R-H không)) (Aa-H đủ) (PP-IOB (Cs-H cho) (NP (Pp-H anh))) (VP-CMP (Vv-H chạy) (NP (Nn-H thận) (ADJP (Aa-H nhân_tạo))) (NP-TMP (Nq vài) (Nu-H tuần))))) (PU .))
#
# Dev_90295 (S (PP-ADV (Cs-H Trên) (NP (Nn-H mặt) (Nn bàn) (NP (Nn-H gỗ)) (PP (Cs-H trong) (NP (Nn-H nhà) (NP-1 (Pp-H anh)))))) (NP-SBJ (NONE *-1)) (VP-CMP (Vv-H phủ) (NP-DOB (Num một) (Nn_swsp (Nc-H tấm) (Nn kính)))) (PU .))
#
# Dev_90295 (SPL (PP-ADV (Cs-H Dưới) (NP (Nn-H mặt) (Nn kính))) (VP (Vc-H là) (NP-CMP (Nq những) (Nn_swsp (Nc-H-1 tấm) (Nn hình)) (VP (Vv-H được) (S-CMP (NP-SBJ (Nn-H anh) (Nr Tăng)) (VP (Vv-H giữ) (NP-DOB (Nn *D*-1)) (PP (Cs-H như) (NP (Num một) (Nn_swsp (Ncs-H niềm) (Aa vui)) (ADJP (Aa-H nho_nhỏ))))))))) (PU .))
#
# Dev_90295 (S (NP-SBJ (Pd-H Đấy)) (VP (Vc-H là) (NP-CMP (Nn-H hình) (VP (Vv-H chụp) (S (NP (NP (Pp-H anh)) (Cp cùng) (NP (Nq các) (Nn_swsp (Nc-H vị) (Nn lãnh_đạo)) (PU ,) (Nn-H thân_nhân) (Cp và) (Nn-H du_khách))) (VP (Vv-H về) (VP (Vv-H thăm) (NP (NP (X-H NTLS) (Nr Trường_Sơn)) (Cp và) (NP (X-H NTLS) (NP (Nn-H Đường) (Nr 9)))))))))) (PU .))
#
# Dev_90295 (S (Cp Giá_như) (S-CND (NP-SBJ (Nn-H bệnh_tật)) (VP (R không) (Vv-H quật_ngã) (NP-DOB (Pp-H anh)))) (PU ,) (S (R có_lẽ) (NP-TMP (Nt-H giờ) (Pd này)) (NP-SBJ (Nn-H anh) (Nr Tăng)) (ADJP-PRD (RP (R vẫn) (R-H đang) (R còn)) (Aa-H tẩn_mẩn) (PP (Cs-H với) (NP (NP (Pp từng) (Nn-H bia_mộ) (SBAR (NONE *-1))) (PU ,) (NP (Pp từng) (Nn_w (Sv đồng) (Nn-H đội)) (SBAR-1 (Cs mà) (S (NP-TMP (Num 25) (Num-H năm) (ADJP (Aa-H qua))) (NP-SBJ (Pp-H anh)) (VP (R đã) (Vv-H gắn_bó) (PP (Cs-H giữa) (ADJP (Aa-H bát_ngát) (NP (Nn-H núi_rừng)))))))))))) (PU .))
#
# Dev_90295 (S (NP-SBJ (Nn-H Dân_gian)) (VP (R thường) (Vv-H tin) (SBAR-CMP (Cs rằng) (S (NP-SBJ (Nq những) (Nn-H người) (NP (Nn-H cõi) (Nn âm))) (VP (ADJP (R luôn) (Aa-H lặng_lẽ) (Aa-H âm_thầm)) (Vv-H độ_trì) (PP-PRP (Cs-H cho) (S (NP-SBJ (Nn-H người) (NP (Nn-H cõi) (Nn dương))) (VP (R vẫn) (ADJP (Aa-H hằng_tâm)) (Vv-H chăm_lo) (PP (Cs-H cho) (NP (Pp-H họ)))))))))) (PU .))
#
# Dev_90295 (S (NP-SBJ (Pp-H Tôi)) (VP (R cũng) (Vv-H muốn) (VP-CMP (Vv-H tin) (PP (Cs-H như) (NP (Pp-H thế))) (PP (Cs-H cho) (NP (Nn-H anh) (Nr Tăng))) (PU ,) (SBAR-CMP (Cs *0*) (S (NP-SBJ (Nn-H hương_hồn) (PP (Cs-H của) (NP (Nq những) (Nn-H liệt_sĩ) (PP (Cs-H trên) (NP (Nw cả) (Num hai) (Nn-H nghĩa_trang) (Nn quốc_gia)))))) (VP (ADJP (Aa-H có_thể)) (Vv-H độ_trì) (PP (Cs-H cho) (NP (Pp-H anh) (PU -) (S-PRN (NP-SBJ (Nn-H người)) (ADJP-TMP (Aa-H suốt) (NP (Nn-H đời))) (VP (Vv-H chăm_sóc) (NP (Nq những) (Nn-H nấm_mồ) (NP (Nn-H liệt_sĩ))))))) (PU -) (PP (Cs-H qua) (NP (M cái) (Nn-H đận) (ADJP (Aa-H hiểm_nghèo)) (Pd này)))))))) (PU .))
#
# Dev_90295 (S (S (NP-SBJ (Pd-H Bây_giờ)) (VP (Vc-H là) (NP-TMP (Nt-H tháng) (Num bảy)))) (PU ,) (S (NP-TMP (Nt-H tháng) (Num bảy) (PP (Cs-H ở) (NP (Nr-H Quảng_Trị)))) (PU ,) (NP-SBJ (ADJP (Aa-H nhiều)) (Nn-H người)) (VP (R vẫn) (Vv-H gọi) (SBAR-CMP (Cs *0*) (S (NP-SBJ (Pd-H đây)) (VP (Vc-H là) (NP-CMP (Nn-H đất) (Aa thiêng))))))) (PU !))
#
# Dev_9539 (SPL-HLN (NP (Nn-H Người) (VP (Vv-H xoá) (VP-CMP (PU ") (Vv-H xóc_chéo) (PU ") (NP-TMP (Nn-H mùa) (Nn lũ))))) (PU .))
#
# Dev_9539 (S (S-CNC (NP-SBJ (NONE *-1)) (VP (Vv-H Nghe) (ADJP (Aa-H nhiều)) (PP (Cs-H về) (NP (Pp-H ông))))) (PU ,) (Cp nhưng) (S (PP-TMP (Cs-H đến) (NP (Nt-H hôm_nay))) (NP-SBJ-1 (Pp-H tôi)) (VP (R mới) (Ve-H có) (NP-CMP (Nn-H dịp) (VP (Vv-H về) (NP-CMP-LOC (Nun-H ấp) (Nr Long_Châu) (An 1) (PU ,) (NP-PRN (Nun-H xã) (Nr Thạnh_Mỹ_Tây) (LBRK LBRK) (NP-PRN (Nr-H Châu_Phú) (PU ,) (NP-PRN (Nr-H An_Giang))) (RBRK RBRK))) (PP-PRP (Cs-H để) (VP (Vv-H gặp) (NP-CMP (Pp-H ông)))))))) (PU .))
#
# Dev_9539 (S (NP-SBJ (Pp-H Người_ta)) (VP (R thường) (Vv-H gọi) (NP-DOB (Pp-H ông)) (VP-CMP (Vc-H là) (NP (Nn-H ông) (Nr Ba_Phước) (LBRK LBRK) (NP-PRN (Nr-H Trần_Văn_Minh)) (RBRK RBRK) (PU -) (NP-PRN (Nn-H người) (VP (R đã) (Vv-H bỏ) (NP-CMP (ADJP (Aa-H nhiều)) (Nn-H công) (Nn-H của) (Cp và) (Nt-H ngày_tháng)) (PP-PRP (Cs-H để) (VP (Vv-H lo) (NP-DOB (Nn-H chỗ) (Vv an_nghỉ) (PP (Cs-H cuối) (NP (Nn-H đời)))) (PP-IOB (Cs-H cho) (NP (Nq những) (Nn_swsp (Nc-H người) (Nn dân)) (ADJP (Aa-H nghèo)) (NP (Nun-H vùng) (Nn lũ))))))))))) (PU ...))
#
# Dev_9539 (SPL-HLN (NP (NP (Nn-H Cái) (VP (Ve-H mất))) (PU ,) (NP (Nn-H cái) (VP (Ve-H còn)))) (PU .))
#
# Dev_9539 (S (NP-TPC-1 (Nn-H Ông) (Nr Ba_Phước)) (S (NP-SBJ (Nn-H vóc) (Nn người) (NP (NONE *T*-1))) (ADJP-PRD (Aa-H nhỏ_nhắn))) (PU ,) (S (NP-SBJ (Nn-H tóc) (NP (NONE *T*-1))) (ADJP-PRD (Aa-H bạc))) (PU ,) (S (NP-SBJ (Nn-H da) (NP (NONE *T*-1))) (ADJP-PRD (Aa-H ngăm_ngăm))) (PU ,) (S (NP-SBJ (Nn-H mặt) (NP (NONE *T*-1))) (VP (Vv-H hiện) (ADJP (Aa-H rõ)) (NP (Nn-H nét) (Vv từng_trải) (PP (Cs-H của) (NP (Num một) (Nn-H ông) (ADJP (Aa-H già) (NP (Num 70) (Nn-H tuổi))) (VP (R đã) (Ve-H có) (NP-CMP (Nw cả) (Nn-H cuộc_đời) (VP (ADJP (Aa-H cần_cù)) (Vv-H lao_động) (ADJP (Aa-H miệt_mài)))))))))) (PU .))
#
# Dev_9539 (S (NP-SBJ (Pp-H Ông)) (VP (VP (Vv-H đứng) (NP (Nn-H bên) (NP (Pp-H tôi)))) (VP (Vv-H nói) (PP-MNR (Cs-H với) (NP (Nn-H giọng) (ADJP (Aa-H tự_hào)))))) (PU .))
#
# Dev_9539 (S (NP-SBJ (Pp-H Chú)) (VP (Vv-H xem) (NP-CMP (Pd-H đó) (PU ,) (S-PRN (S (NP-SBJ (Nw cả) (Nn-H cơ_sở) (VP (Vv-H sản_xuất) (NP (Nn-H nước_mắm))) (Nr Phước_Hương)) (NP-TMP (Num một) (Nu-H năm)) (VP (Vv-H làm) (R ra) (NP-DOB (QP (R gần) (Num-H 2.000)) (Nu-H tấn) (Nn nước_mắm)))) (PU ,) (S (NP-SBJ (QP (Nw cả) (Nq-H chục)) (Nn-H hầm) (VP (Vv-H nuôi) (NP (Nn-H cá)))) (PU ,) (NP-TMP (Nt-H hiện)) (VP (Ve-H có) (NP-CMP (QP (R trên) (Num-H 600.000)) (Nn_swsp (Nc-H con) (Nn cá_tra)))))))) (PU ...))
#
# Dev_9539 (S (S-CNC (NP-SBJ-1 (Nw Tất_cả) (Nn-H tài_sản) (PP (Cs-H của) (NP (Pp-H tui))) (NP-TMP (Nt-H giờ_đây))) (UCP-PRD (NP (QP (R trên) (Num-H 3) (Nq-H tỉ)) (Nn-H bạc)) (Cp rồi) (VP (RP (R sẽ) (R-H chẳng) (R còn)) (Vc-H là) (PP-CMP (Cs-H của) (NP (Pp-H tui))) (R nữa)))) (PU ,) (Cp nhưng) (S (NP-SBJ (Nn_swsp (Nc-H cái) (Nn nghĩa_địa)) (Pd đó)) (VP (R mới) (Vc-H là) (PP-CMP (Cs-H của) (NP (Pp-H tui))))) (PU ...))
#
# Dev_9539 (S (NP-SBJ (Pp-H Tôi)) (VP (VP (Vv-H nhìn) (VP-MNR (Vv-H theo) (NP (Nn-H hướng) (SBAR (Cs *0*) (S (NP-SBJ (Nn-H cánh_tay) (PP (Cs-H của) (NP (Nn-H ông) (Nr Ba_Phước)))) (VP (Vv-H chỉ)))) (PU ,) (VP-PRN (PP (Cs-H từ) (NP (Nn_swsp (Nc-H căn) (Nn nhà)) (VP (Vv-H đúc)) (VP (Vv-H nằm) (NP (Nn-H ven) (NP (Nn_swsp (Nc-H con) (Nn kênh_xáng)) (Nr Vịnh_Tre)))))) (Vv-H vòng) (PP (Cs-H qua) (NP (NP (Nq mấy) (Nn-H dãy) (NP (Nn-H nhà_kho) (VP (Vv-H ủ) (NP (Nn-H nước_mắm))) (ADJP (NONE *-1)))) (PU ,) (NP (Nq mấy) (Nn-H hầm) (VP (Vv-H nuôi) (NP (Nn-H cá_tra))) (ADJP-1 (R đang) (Aa-H lố_nhố) (S (NP-SBJ (QP (Nq mấy) (Nq-H chục)) (Nn-H công_nhân)) (VP (Vv-H làm_việc))))))))))) (Cp mà) (VP (ADJP (Aa-H thầm)) (Vv-H khâm_phục) (NP-CMP (Nn_swsp (Nc-H-2 người) (Nn nông_dân)) (VP (R chỉ) (Vv-H tốt_nghiệp) (NP (Nn-H tiểu_học) (NP (Nn-H trường) (NP (Nun-H làng))))) (PU ,) (S-PRN (PP-MNR (Cs-H từ) (NP (Nn-H bàn_tay) (Aa trắng))) (NP-SBJ (Nn *H*-2)) (VP (R đã) (Vv-H tạo_lập) (VP (Vv-H nên) (NP-CMP (Nn-H cơ_nghiệp)))))))) (PU ...))
#
# Dev_9539 (S (NP-SBJ (Nr-H Ba_Phước)) (VP (VP (R đang) (Vc-H là) (NP-CMP (Nn-H chủ_tịch) (NP (Nn-H hội_đồng) (Vv quản_trị) (NP (Nn-H doanh_nghiệp) (Nn tư_nhân) (VP (Vv-H sản_xuất) (NP (Nn-H nước_mắm))) (Nr Phước_Hương))))) (PU ,) (Cp nhưng) (VP (R lại) (Vv-H bảo) (SBAR-CMP (Cs *0*) (S (NP-SBJ (Nn-H cơ_nghiệp) (Pd đó)) (PP-PRD (RP (R sẽ) (R-H chẳng)) (M là) (Cs-H của) (NP (Pp-H mình)) (PU ,) (SBAR-PRP (Cs bởi) (S (VP-MNR (Vv-H theo) (NP (Nn-H cách) (Vv nói) (PP (Cs-H của) (NP (Pp-H ông))))) (PU ,) (NP-SBJ-1 (Nn-H cơ_nghiệp) (SBAR (Cs *0*) (S (NP-SBJ (Pp-H ông)) (VP (Vv-H tạo_lập) (VP (Vv-H nên)))))) (VP (R đã) (Vv-H được) (VP-CMP (Vv-H chia) (NP-DOB (NONE *T*-1)) (PP-IOB (Cs-H cho) (NP (Nn-H con_cháu)))))))))))) (PU .))
#
# Dev_9539 (S (NP-SBJ (Pp-H Chúng)) (VP (RP (R-H đã) (Cp và) (R-H đang)) (ADJP (Aa-H trực_tiếp)) (VP (Vv-H tổ_chức) (VP-CMP (Vv-H sản_xuất) (Vv-H kinh_doanh)))) (PU .))
#
# Dev_9539 (S (NP-TMP (Nt-H Mai) (Pd này)) (NP-TPC-2 (Nn-H chuyện) (VP (VP (Vv-H-1 tồn_tại) (Cp và) (Vv-H-1 phát_triển)) (Cp hay) (VP (R không) (Vv *H*-1)))) (NP-SBJ (Pp-H ông)) (VP (R không) (Vv-H biết) (NP-CMP (NONE *T*-2)) (ADJP (Aa-H chắc)) (R được)) (PU .))
#
# Dev_9539 (S (SPL-CNC (NP (Pp-H Thế))) (Cp nhưng) (S (NP-SBJ (Nn_swsp (Nc-H cái) (Nn nghĩa_địa)) (ADJP (Aa-H rộng) (NP (QP (R trên) (Num-H 7.000)) (Nu-H m2))) (PP-LOC (Cs-H ở) (NP (Nun-H ấp) (Nr Long_Châu) (An 1) (PU ,) (NP-PRN (Nun-H xã) (Nr Thạnh_Mỹ_Tây) (PU ,) (NP-PRN (Nun-H huyện) (Nr Châu_Phú) (LBRK LBRK) (NP-PRN (Nr-H An_Giang)) (RBRK RBRK))))) (VP (Vv-H mang) (NP-CMP (Nn-H tên) (Nr Từ_Thiện))) (SBAR (Cs mà) (S (NP-SBJ (Pp-H ông)) (VP (R đã) (Vv-H tốn) (NP-CMP (R biết_bao) (Nn-H công_sức) (Vv xây_dựng)))))) (VP (ADJP (Aa-H chắc_chắn)) (R sẽ) (Vv-H tồn_tại) (Cp và) (Vv-H phát_triển))) (PU .))
#
# Dev_9539 (S (NP-SBJ (Nr-H Ba_Phước)) (VP (Vv-H tâm_sự) (SBAR-CMP (Cs *0*) (PU :) (PU ") (S (NP-SBJ (Pp-H Chú)) (VP (Vv-H biết) (M đó))))) (PU .))
#
# Dev_9539 (S (NP-SBJ (Nn-H Đất) (NP (Nn-H xứ) (Pd này))) (ADJP-PRD (Aa-H thấp)) (PU .))
#
# Dev_9539 (S (NP-TMP (Nn-H Mùa) (NP (Nn-H nước) (Vv nổi)) (VP (Vv-H dâng) (D lên))) (VP (Ve-H có) (S-CMP (NP-SBJ (Nn-H chỗ)) (VP (Vv-H ngập) (NP (QP (R trên) (Num-H 2,5)) (Nu-H m))))) (PU .))
#
# Dev_9539 (S (PP-ADV (Cs-H Với) (NP-1 (ADJP (Aa-H nhiều)) (Nn-H gia_đình) (ADJP (Aa-H nghèo)))) (NP-TPC-2 (Nn-H chỗ) (ADJP (Aa-H cao_ráo)) (PP-PRP (Cs-H để) (VP (Vv-H cất) (NP (Nn-H nhà) (Vv ở))))) (NP-SBJ (NONE *-1)) (VP (RP (R còn) (R-H không)) (Ve-H có) (NP-CMP (NONE *T*-2))) (PU .))
#
# Dev_9539 (S (S (NP-SBJ (NONE *E*)) (VP (Vv-H Nói) (NP-CMP (Pp-H chi)) (NP (M đến) (Nn-H chỗ) (VP (Vv-H an_táng) (NP-1 (Nn-H người_thân)))))) (Cp nếu) (S-CND (NP-SBJ (NONE *-1)) (VP (ADJP-PRD (R không) (Aa-H may)) (Vv-H chết) (PP-TMP (Cs-H vào) (NP (Nn-H mùa) (NP (Nn-H nước) (Vv nổi)))))) (PU .))
#
# Dev_9539 (S (NP-SBJ (Pp-H Chú)) (VP (Cp mà) (VP (Vv-H thấy) (NP-CMP (Nn-H cảnh) (VP (Vv-H chôn) (NP-DOB (Nn-H người) (Vv chết)) (NP-TMP (Nn-H mùa) (NP (Nn-H nước) (Vv nổi)))))) (Cp mới) (VP (VA-H xót_xa))) (PU .))
#
# Dev_9539 (S (NP-TMP (Nt-H Lúc) (Pd đó)) (NP-SBJ (Pp-H người_ta)) (VP (Vv-H phải) (VP-CMP (VP (Vv-H ra_công) (VP (Vv-H ghép) (NP-DOB (Nn-H ván)))) (PU ,) (VP (Vv-H cắm) (ADJP (Aa-H cứng)) (PP (Cs-H xuống) (NP (Nn-H nước)))) (PU ,) (VP (Vv-H ém) (ADJP (Aa-H kín))) (Cp rồi) (VP (Vv-H bơm) (NP-DOB (Nn-H nước)) (R ra) (PP-PRP (Cs-H để) (VP (Vv-H đào) (NP-DOB (Nn-H đất))))))) (PU .))
#
# Dev_9539 (S (SPL-PRP (NP-TMP (Nt-H Khi) (SBAR (Cs *0*) (S (NP-SBJ (NONE *E*)) (VP (Vv-H đặt) (NP-DOB (Nn-H quan_tài)) (D xuống))))) (Cp mà) (PP-ADV (Cs-H dưới) (NP (Nn-H huyệt))) (VP (Ve-H có) (NP-CMP (Nn-H nước)))) (PU ,) (S (NP-SBJ (Nn-H quan_tài)) (VP (VP (R cứ) (Vv-H nổi) (R lên) (VP (Vv-H bập_bềnh))) (VP (R chẳng) (Vv-H chịu) (VP-CMP (Vv-H nằm) (ADJP (Aa-H im)))))) (PU ,) (S (NP-SBJ (NONE *E*)) (VP (VP (Vv-H phải) (VP-CMP (Vv-H đè) (D xuống))) (Cp và) (VP (Vv-H đổ) (ADJP (Aa-H nhanh)) (NP-DOB (Nn-H đất)) (VP-PRP (Vv-H lấp) (R lại))))) (PU .))
#
# Dev_9539 (S (S-PRP (NP-SBJ (NONE *-1)) (VP (R-H Không) (Ve-H có) (NP-CMP (Nn-H đất) (ADJP (Aa-H gần))))) (PU ,) (S (NP-SBJ-1 (Pp-H người_ta)) (VP (Vv-H phải) (VP-CMP (Vv-H mang) (NP-DOB (Nn-H người) (Vv chết)) (PP (Cs-H lên) (NP (Nn-H vùng) (Nr Bảy_Núi))) (PP-PRP (Nr-H để) (VP (Vv-H chôn_cất))) (UCP-PRN (ADJP (Aa-H xa_xôi)) (PU ,) (VP (Vv-H tốn_kém) (PU ,) (S-PRN (NP-SBJ (R chỉ) (Nn-H nhà) (ADJP (Aa-H giàu))) (VP (R mới) (Vv-H lo) (R nổi)))))))) (PU ...))
#
# Dev_9539 (SPL (NP-TMP (Nn-H Mùa) (NP (Nn-H nước) (Vv nổi))) (PU ,) (VP (Ve-H có) (S-CMP (NP-SBJ-1 (Nn-H gia_đình) (ADJP (Aa-H nghèo_khổ) (R quá))) (VP (VP (Vv-H phải) (VP-CMP (Vv-H để) (NP-DOB (Nn-H quan_tài)) (PP-MNR (Cs-H trên) (NP (Nn-H giàn) (NP (Nn-H gỗ)) (PP (Cs-H giữa) (NP (Nn-H đồng) (Nn nước) (ADJP (Aa-H mênh_mông)))))))) (PU ,) (VP (Vv-H chờ) (SBAR-CMP (Cs *0*) (S (NP-TMP (Nn-H nước) (VP (Vv-H rút))) (NP-SBJ (NONE *-1)) (VP (R mới) (Vv-H chôn)))))))) (PU .))
#
# Dev_9539 (S (S (NP-TPC-1 (Nn-H Cách) (Vv an_táng) (Pd này)) (NP-SBJ (Pp-H người_ta)) (VP (R thường) (Vv-H gọi) (NP-DOB (NONE *T*-1)) (PP-CMP (Cs-H bằng) (NP (Nn-H từ) (PU ") (Vv xóc_chéo) (PU "))))) (PU ,) (S (NP-SBJ (NONE *E*)) (VP (Vv-H thấy) (ADJP-CMP (Aa-H thương_tâm) (R lắm))) (NP-VOC (Pp-H chú))) (PU ...))
#
# Dev_9539 (S (NP-SBJ (Nn-H Ông) (Nr Ba_Phước)) (VP (R còn) (Vv-H kể) (PP-IOB (Cs-H cho) (NP (Pp-H tôi))) (VP-CMP (Vv-H nghe) (NP-CMP (Nn-H nguồn_gốc) (VP (Vv-H hình_thành) (NP (Nn-H nghĩa_địa) (Pd này)))))) (PU .))
#
# Dev_9539 (S (PP-LOC (Cs-H Tại) (NP (Nn-H nơi) (Pd đây))) (PU ,) (NP-TMP (Nt-H trước_kia)) (NP-SBJ-2 (Nn-H khoảng) (Nn đất) (ADJP (R chỉ) (Aa-H rộng) (NP (Num 1.634) (Nu-H m2))) (PP (Cs-H của) (NP (Nn-H ông) (Nr Nguyễn_Văn_Tâm))) (PU ,) (VP-PRN (VP (Vc-H là) (NP-CMP (Nn-H gò) (Nn đất) (ADJP (R hơi) (Aa-H cao)))) (PU ,) (VP (Vv-H cho_phép) (NP-IOB (Nn-H bà_con) (PP-LOC (Cs-H trong) (NP (Nn-H vùng)))) (VP-CMP (Vv-H chôn_cất) (NP-DOB-1 (Nn-H người_thân)) (NP-TMP (Nt-H khi) (SBAR (Cs *0*) (S (NP-SBJ (NONE *-1)) (VP (Vv-H qua_đời)))))))) (PU ,)) (VP (Vv *P*) (VP-CMP (Vv-H gọi) (NP-DOB (NONE *T*-2)) (PP-CMP (Cs-H là) (NP (Nn-H nhị_tì))))) (PU ...))
